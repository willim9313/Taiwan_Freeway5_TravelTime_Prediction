# %% [markdown]
# # Data Cleansing

# %% [markdown]
# 這個notebook主要說明下載完畢的資料要做什麼樣的基本處理才可以進入EDA的流程
# 先前下載的資料多數為xml file，基本的結構不適合分析師直接操作
# 這邊會說明如何透過封裝好的function來:
# * 解壓縮文件(.tar, .xml.gz)
# * 資料結構化
# * 資料儲存(這邊採用sqlite)

# %% [markdown]
# # Lib

# %%
import pandas as pd
from tqdm import tqdm
import os
import time
import sys

# 將 hwttp 資料夾加入 Python 搜尋路徑
sys.path.append(os.path.abspath('..'))
import hwttp.data_scraper as ds

# %%
import hwttp.data_cleaning as dc

# %% [markdown]
# # Unzip data

# %% [markdown]
# 注意解壓縮的時間範圍，因為原始檔案大小會佔據一定空間，貿然解壓縮可能會導致硬碟滿載
# 建議第一次先解壓縮五天就好，再視自己的空間許可進行變更

# %%
date_list = []
start_date = '20231101'
end_date = '20231101'
date_list = ds.generate_date_strings(start_date, end_date)

# %% [markdown]
# ## VD data

# %% [markdown]
# 這邊在處理上沒有特別區分靜態跟動態的VD資料，只要在對應的資料夾底下就可以一起解壓縮

# %%
dc.decompress_vd_data(date_list)
# Out:
# 100%|██████████| 1/1 [00:23<00:00, 23.42s/it]

# %% [markdown]
# ## ETag Info Data

# %% [markdown]
# 1個月資料大小大概5GB，需要用的時候再解壓縮

# %%
dc.decompress_etag_info_data(date_list)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.94s/it]

# %% [markdown]
# ## ETag vol Data

# %%
dc.decompress_etag_vol_data(date_list)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]

# %% [markdown]
# ## ETag Speed Data

# %%
dc.decompress_etag_speed_data(date_list)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.51it/s]

# %% [markdown]
# ## ETag Travel Time Data

# %%
dc.decompress_etag_intergantry_traveltime_data(date_list)
# Out:
# 100%|██████████| 30/30 [00:00<00:00, 43.03it/s]

# %% [markdown]
# # Data ETL & store into sqlite DB

# %% [markdown]
# 這部分會將xml結構的資料先轉換成dict，每種資料源的dict結構又會不太一樣，因此會使用獨立的function來轉換成dataframe
# 這邊的目標是將dataframe全數儲存在db中，日後視需求再用sql撈取資料進行分析
# 但需要注意的是儲存空間是否充足，因為資料的顆粒度很細，以sqlite儲存還是有一定負擔
# 以下每個區塊會先附上原始資料平台所提供的schema做為參考

# %% [markdown]
# 資料的操作與儲存上在以下依據量體會分成兩種處理方式:
# * 所有資料儲存在同一張表: VD Static, VD Dynamic, ETag Static, ETag Pair, ETag Pair Live
#     * 處理的腳本相對簡單
# * 資料依據時間維度分拆不同張表: ETag Vol, ETag Speed, ETag Travel Time
#     * 處理的腳本相對複雜，額外於組裝多個條件邏輯進行判斷

# %% [markdown]
# ## VD Static

# %% [markdown]
# 一天資料筆數 3,878筆

# %%
# UpdateTime：	本平台資料更新時間(ISO8601格式:yyyy-MM-ddTHH:mm:sszzzz)
# UpdateInterval：	本平台資料更新週期(秒)
# AuthorityCode：	業管機關簡碼
# VDID：	VD設備代碼
# SubAuthorityCode：	業管子機關簡碼
# BiDirectional：	是否為雙向偵測 = ['0: 偵測單向', '1: 偵測雙向']
# LinkID：	基礎路段代碼, 請參閱[基礎路段代碼表]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# Bearing：	基礎路段方位 = ['N: 北', 'E: 東', 'W: 西', 'S: 南', 'NE: 東北', 'SE: 東南', 'NW: 西北', 'SW: 西南']
# RoadDirection：	基礎路段所屬道路方向, 請參閱[道路方向資料表]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# LaneNum：	設備於該方向基礎路段所能偵側車道數
# ActualLaneNum：	該方向基礎路段的實際車道數
# VDType：	VD 類別 = ['1: 線圈式', '2: 微波式', '3: 影像式', '4: 紅外線', '5: 超音波', '6: 其它']
# LocationType：	設置地點位置類型 = ['1: 路側', '2: 道路中央分隔島', '3: 快慢分隔島', '4: 車道上門架', '5: 車道鋪面', '6: 其他']
# DetectionType：	車流偵側類型 = ['1: 高快速公路/市快主線', '2: 高快速公路/市快匝道', '3: 其它道路路段中', '4: 其它道路路口(靠近路口或停止線)']
# PositionLon：	設備架設位置 X 坐標
# PositionLat：	設備架設位置 Y 坐標
# RoadID：	道路代碼, 請參閱[路名碼基本資料]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# RoadName：	道路名稱
# RoadClass：	道路分類 = ['0: 國道', '1: 快速道路', '2: 市區快速道路', '3: 省道', '4: 縣道', '5: 鄉道', '6: 市區一般道路', '7: 匝道']
# Start：	路段起點描述
# End：	路段迄點描述
# LocationMile：	所在方向里程數

# %% [markdown]
# 這邊會先實體化一個db，需要指定table_name以及他的欄位名稱(依照順序)
# 後續就是建立table，以及call function完成指定資料的清洗、轉換、儲存

# %%
db_path = "../data/hwdb.db"
table_name = "VD_STATIC"
columns_in_order = '''
UpdateTime, UpdateInterval, AuthorityCode, VDID, SubAuthorityCode, 
BiDirectional, LinkID, Bearing, RoadDirection, Lane,
ActualLaneNum, VDType, LocationType, DetectionType, PositionLon,
PositionLat, RoadID, RoadName, RoadClass, Start, 
End, LocationMile
'''

vd_static_tb = dc.DatabaseManager(db_path=db_path, 
                                  table_name=table_name)

# %%
# 建立table
vd_static_tb.initialize_table(columns_in_order)

# %%
# Usage 實際需要塞資料時，請參考這邊，使用date_list去找到已經解壓縮路徑底下的資料
# 資料會需要先從xml解析成dict，過程中已經根據原始結構自訂好處理方式了
# 從dict轉換成df的時候會做一些特殊的處理，因為不同資料的字典結構會不太一樣

for date in tqdm(date_list):
    # VD_STATIC的資料都是以 "VD_0000.xml" 儲存
    xml_file_path = f'../data/raw/unzip_VD/{date}/VD_0000.xml'
    vd_0000 = dc.convert_xml_to_dict(xml_file_path)
    df = dc.vd_static_dict_to_df(vd_0000)
    vd_static_tb.append_data(df) # 可替換成update_data處理
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  3.32it/s]

# %%
# 如果需要刪除整張table的話
# vd_static_tb.delete_table_data()
# 如果怕資料有重複倒入，可以用update_data的方式處理，但會慢一些，因為要比對key value
# vd_static_tb.update_data(df, ['UpdateTime', 'LinkID'])

# %% [markdown]
# ## VD Dynamic

# %% [markdown]
# 一天的資料比數大概是 25236*1441 = 36,365,076 筆

# %%
# UpdateTime：	本平台資料更新時間(ISO8601格式:yyyy-MM-ddTHH:mm:sszzzz)
# UpdateInterval：	本平台資料更新週期(秒)
# AuthorityCode：	業管機關簡碼
# VDID：	VD設備代碼
# LinkID：	基礎路段代碼, 請參閱[基礎路段代碼表]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# LaneID：	車道代碼
# LaneType：	車道種類 = ['1: 一般車道', '2: 快車道', '3: 慢車道', '4: 機車道', '5: 高承載車道', '6: 公車專用道', '7: 轉向車道', '8: 路肩', '9: 輔助車道', '10: 調撥車道', '11: 其他']
# Speed：	平均速率偵測值, ['-99=資料異常', '-1=道路封閉']
# Occupancy：	佔有率偵測值
# VehicleType：	車種代碼, 請參閱[車種代碼]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# Volume：	流量偵測值, -99=資料異常
# speed(2)：	平均速率偵測值, -99=資料異常
# Status：	設備狀態 = ['0: 正常', '1: 通訊異常', '2: 停用或施工中', '3: 設備故障']
# DataCollectTime：	資料蒐集時間(ISO8601格式:yyyy-MM-ddTHH:mm:sszzzz)

# %%
db_path = "../data/hwdb.db"
table_name = "VD_DYNAMIC"
columns_in_order = '''
UpdateTime, UpdateInterval, AuthorityCode, VDID, LinkID, 
LaneID, LaneType, Speed, Occupancy, VehicleType,
Volume, Speed2, Status, DataCollectTime
'''

vd_dynamic_tb = dc.DatabaseManager(db_path=db_path, 
                                  table_name=table_name)

# %%
# 建立table
vd_dynamic_tb.initialize_table(columns_in_order)

# %%
date_list
# Out:
# ['20231101']

# %%
# Usage 實際需要塞資料時，請參考這邊，使用date_list去找到已經解壓縮路徑底下的資料
# 資料會需要先從xml解析成dict，過程中已經根據原始結構自訂好處理方式了
# 從dict轉換成df的時候會做一些特殊的處理，因為不同資料的字典結構會不太一樣

for date in tqdm(date_list):
    # VD_DYNAMIC 的資料都是以 "VDLive_XXXX.xml" 儲存
    # xml_file_path = f'../data/raw/unzip_VD/{date}/VD_0000.xml'
    upper_file_path = f'../data/raw/unzip_VD/{date}/'
    file_name_list = os.listdir(upper_file_path)
    file_name_list = [file for file in file_name_list if file.startswith('VDLive')]

    for file in tqdm(file_name_list):
        xml_file_path = upper_file_path + file
        vdlive_0000 = dc.convert_xml_to_dict(xml_file_path)
        df = dc.vd_dynamic_dict_to_df(vdlive_0000)
        vd_dynamic_tb.append_data(df) # 可替換成update_data處理
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ../data/raw/unzip_VD/20231101/VDLive_0000.xml
# ../data/raw/unzip_VD/20231101/VDLive_0001.xml
# ../data/raw/unzip_VD/20231101/VDLive_0002.xml
# ../data/raw/unzip_VD/20231101/VDLive_0003.xml
# ../data/raw/unzip_VD/20231101/VDLive_0004.xml
# ../data/raw/unzip_VD/20231101/VDLive_0005.xml
# ../data/raw/unzip_VD/20231101/VDLive_0006.xml
# ../data/raw/unzip_VD/20231101/VDLive_0007.xml
# ../data/raw/unzip_VD/20231101/VDLive_0008.xml
# ../data/raw/unzip_VD/20231101/VDLive_0009.xml
# ../data/raw/unzip_VD/20231101/VDLive_0010.xml
# ../data/raw/unzip_VD/20231101/VDLive_0011.xml
# ../data/raw/unzip_VD/20231101/VDLive_0012.xml
# ../data/raw/unzip_VD/20231101/VDLive_0013.xml
# ../data/raw/unzip_VD/20231101/VDLive_0014.xml
# ../data/raw/unzip_VD/20231101/VDLive_0015.xml
# ../data/raw/unzip_VD/20231101/VDLive_0016.xml
# ../data/raw/unzip_VD/20231101/VDLive_0017.xml
# ../data/raw/unzip_VD/20231101/VDLive_0018.xml
# ../data/raw/unzip_VD/20231101/VDLive_0019.xml
# ../data/raw/unzip_VD/20231101/VDLive_0020.xml
# ../data/raw/unzip_VD/20231101/VDLive_0021.xml
# ../data/raw/unzip_VD/20231101/VDLive_0022.xml
# ../data/raw/unzip_VD/20231101/VDLive_0023.xml
# ../data/raw/unzip_VD/20231101/VDLive_0024.xml
# ../data/raw/unzip_VD/20231101/VDLive_0025.xml
# ../data/raw/unzip_VD/20231101/VDLive_0026.xml
# ../data/raw/unzip_VD/20231101/VDLive_0027.xml
# ../data/raw/unzip_VD/20231101/VDLive_0028.xml
# ../data/raw/unzip_VD/20231101/VDLive_0029.xml
# ../data/raw/unzip_VD/20231101/VDLive_0030.xml
# ../data/raw/unzip_VD/20231101/VDLive_0031.xml
# ../data/raw/unzip_VD/20231101/VDLive_0032.xml
# ../data/raw/unzip_VD/20231101/VDLive_0033.xml
# ../data/raw/unzip_VD/20231101/VDLive_0034.xml
# ../data/raw/unzip_VD/20231101/VDLive_0035.xml
# ../data/raw/unzip_VD/20231101/VDLive_0036.xml
# ../data/raw/unzip_VD/20231101/VDLive_0037.xml
# ../data/raw/unzip_VD/20231101/VDLive_0038.xml
# ../data/raw/unzip_VD/20231101/VDLive_0039.xml
# ../data/raw/unzip_VD/20231101/VDLive_0040.xml
# ../data/raw/unzip_VD/20231101/VDLive_0041.xml
# ../data/raw/unzip_VD/20231101/VDLive_0042.xml
# ../data/raw/unzip_VD/20231101/VDLive_0043.xml
# ../data/raw/unzip_VD/20231101/VDLive_0044.xml
# ../data/raw/unzip_VD/20231101/VDLive_0045.xml
# ../data/raw/unzip_VD/20231101/VDLive_0046.xml
# ../data/raw/unzip_VD/20231101/VDLive_0047.xml
# ../data/raw/unzip_VD/20231101/VDLive_0048.xml
# ../data/raw/unzip_VD/20231101/VDLive_0049.xml
# ../data/raw/unzip_VD/20231101/VDLive_0050.xml
# ../data/raw/unzip_VD/20231101/VDLive_0051.xml
# ../data/raw/unzip_VD/20231101/VDLive_0052.xml
# ../data/raw/unzip_VD/20231101/VDLive_0053.xml
# ../data/raw/unzip_VD/20231101/VDLive_0054.xml
# ../data/raw/unzip_VD/20231101/VDLive_0055.xml
# ../data/raw/unzip_VD/20231101/VDLive_0056.xml
# ../data/raw/unzip_VD/20231101/VDLive_0057.xml
# ../data/raw/unzip_VD/20231101/VDLive_0058.xml
# ../data/raw/unzip_VD/20231101/VDLive_0059.xml
# ../data/raw/unzip_VD/20231101/VDLive_0100.xml
# ../data/raw/unzip_VD/20231101/VDLive_0101.xml
# ../data/raw/unzip_VD/20231101/VDLive_0102.xml
# ../data/raw/unzip_VD/20231101/VDLive_0103.xml
# ../data/raw/unzip_VD/20231101/VDLive_0104.xml
# ../data/raw/unzip_VD/20231101/VDLive_0105.xml
# ../data/raw/unzip_VD/20231101/VDLive_0106.xml
# ../data/raw/unzip_VD/20231101/VDLive_0107.xml
# ../data/raw/unzip_VD/20231101/VDLive_0108.xml
# ../data/raw/unzip_VD/20231101/VDLive_0109.xml
# ../data/raw/unzip_VD/20231101/VDLive_0110.xml
# ../data/raw/unzip_VD/20231101/VDLive_0111.xml
# ../data/raw/unzip_VD/20231101/VDLive_0112.xml
# ../data/raw/unzip_VD/20231101/VDLive_0113.xml
# ../data/raw/unzip_VD/20231101/VDLive_0114.xml
# ../data/raw/unzip_VD/20231101/VDLive_0115.xml
# ../data/raw/unzip_VD/20231101/VDLive_0116.xml
# ../data/raw/unzip_VD/20231101/VDLive_0117.xml
# ../data/raw/unzip_VD/20231101/VDLive_0118.xml
# ../data/raw/unzip_VD/20231101/VDLive_0119.xml
# ../data/raw/unzip_VD/20231101/VDLive_0120.xml
# ../data/raw/unzip_VD/20231101/VDLive_0121.xml
# ../data/raw/unzip_VD/20231101/VDLive_0122.xml
# ../data/raw/unzip_VD/20231101/VDLive_0123.xml
# ../data/raw/unzip_VD/20231101/VDLive_0124.xml
# ../data/raw/unzip_VD/20231101/VDLive_0125.xml
# ../data/raw/unzip_VD/20231101/VDLive_0126.xml
# ../data/raw/unzip_VD/20231101/VDLive_0127.xml
# ../data/raw/unzip_VD/20231101/VDLive_0128.xml
# ../data/raw/unzip_VD/20231101/VDLive_0129.xml
# ../data/raw/unzip_VD/20231101/VDLive_0130.xml
# ../data/raw/unzip_VD/20231101/VDLive_0131.xml
# ../data/raw/unzip_VD/20231101/VDLive_0132.xml
# ../data/raw/unzip_VD/20231101/VDLive_0133.xml
# ../data/raw/unzip_VD/20231101/VDLive_0134.xml
# ../data/raw/unzip_VD/20231101/VDLive_0135.xml
# ../data/raw/unzip_VD/20231101/VDLive_0136.xml
# ../data/raw/unzip_VD/20231101/VDLive_0137.xml
# ../data/raw/unzip_VD/20231101/VDLive_0138.xml
# ../data/raw/unzip_VD/20231101/VDLive_0139.xml
# ../data/raw/unzip_VD/20231101/VDLive_0140.xml
# ../data/raw/unzip_VD/20231101/VDLive_0141.xml
# ../data/raw/unzip_VD/20231101/VDLive_0142.xml
# ../data/raw/unzip_VD/20231101/VDLive_0143.xml
# ../data/raw/unzip_VD/20231101/VDLive_0144.xml
# ../data/raw/unzip_VD/20231101/VDLive_0145.xml
# ../data/raw/unzip_VD/20231101/VDLive_0146.xml
# ../data/raw/unzip_VD/20231101/VDLive_0147.xml
# ../data/raw/unzip_VD/20231101/VDLive_0148.xml
# ../data/raw/unzip_VD/20231101/VDLive_0149.xml
# ../data/raw/unzip_VD/20231101/VDLive_0150.xml
# ../data/raw/unzip_VD/20231101/VDLive_0151.xml
# ../data/raw/unzip_VD/20231101/VDLive_0152.xml
# ../data/raw/unzip_VD/20231101/VDLive_0153.xml
# ../data/raw/unzip_VD/20231101/VDLive_0154.xml
# ../data/raw/unzip_VD/20231101/VDLive_0155.xml
# ../data/raw/unzip_VD/20231101/VDLive_0156.xml
# ../data/raw/unzip_VD/20231101/VDLive_0157.xml
# ../data/raw/unzip_VD/20231101/VDLive_0158.xml
# ../data/raw/unzip_VD/20231101/VDLive_0159.xml
# ../data/raw/unzip_VD/20231101/VDLive_0200.xml
# ../data/raw/unzip_VD/20231101/VDLive_0201.xml
# ../data/raw/unzip_VD/20231101/VDLive_0202.xml
# ../data/raw/unzip_VD/20231101/VDLive_0203.xml
# ../data/raw/unzip_VD/20231101/VDLive_0204.xml
# ../data/raw/unzip_VD/20231101/VDLive_0205.xml
# ../data/raw/unzip_VD/20231101/VDLive_0206.xml
# ../data/raw/unzip_VD/20231101/VDLive_0207.xml
# ../data/raw/unzip_VD/20231101/VDLive_0208.xml
# ../data/raw/unzip_VD/20231101/VDLive_0209.xml
# ../data/raw/unzip_VD/20231101/VDLive_0210.xml
# ../data/raw/unzip_VD/20231101/VDLive_0211.xml
# ../data/raw/unzip_VD/20231101/VDLive_0212.xml
# ../data/raw/unzip_VD/20231101/VDLive_0213.xml
# ../data/raw/unzip_VD/20231101/VDLive_0214.xml
# ../data/raw/unzip_VD/20231101/VDLive_0215.xml
# ../data/raw/unzip_VD/20231101/VDLive_0216.xml
# ../data/raw/unzip_VD/20231101/VDLive_0217.xml
# ../data/raw/unzip_VD/20231101/VDLive_0218.xml
# ../data/raw/unzip_VD/20231101/VDLive_0219.xml
# ../data/raw/unzip_VD/20231101/VDLive_0220.xml
# ../data/raw/unzip_VD/20231101/VDLive_0221.xml
# ../data/raw/unzip_VD/20231101/VDLive_0222.xml
# ../data/raw/unzip_VD/20231101/VDLive_0223.xml
# ../data/raw/unzip_VD/20231101/VDLive_0224.xml
# ../data/raw/unzip_VD/20231101/VDLive_0225.xml
# ../data/raw/unzip_VD/20231101/VDLive_0226.xml
# ../data/raw/unzip_VD/20231101/VDLive_0227.xml
# ../data/raw/unzip_VD/20231101/VDLive_0228.xml
# ../data/raw/unzip_VD/20231101/VDLive_0229.xml
# ../data/raw/unzip_VD/20231101/VDLive_0230.xml
# ../data/raw/unzip_VD/20231101/VDLive_0231.xml
# ../data/raw/unzip_VD/20231101/VDLive_0232.xml
# ../data/raw/unzip_VD/20231101/VDLive_0233.xml
# ../data/raw/unzip_VD/20231101/VDLive_0234.xml
# ../data/raw/unzip_VD/20231101/VDLive_0235.xml
# ../data/raw/unzip_VD/20231101/VDLive_0236.xml
# ../data/raw/unzip_VD/20231101/VDLive_0237.xml
# ../data/raw/unzip_VD/20231101/VDLive_0238.xml
# ../data/raw/unzip_VD/20231101/VDLive_0239.xml
# ../data/raw/unzip_VD/20231101/VDLive_0240.xml
# ../data/raw/unzip_VD/20231101/VDLive_0241.xml
# ../data/raw/unzip_VD/20231101/VDLive_0242.xml
# ../data/raw/unzip_VD/20231101/VDLive_0243.xml
# ../data/raw/unzip_VD/20231101/VDLive_0244.xml
# ../data/raw/unzip_VD/20231101/VDLive_0245.xml
# ../data/raw/unzip_VD/20231101/VDLive_0246.xml
# ../data/raw/unzip_VD/20231101/VDLive_0247.xml
# ../data/raw/unzip_VD/20231101/VDLive_0248.xml
# ../data/raw/unzip_VD/20231101/VDLive_0249.xml
# ../data/raw/unzip_VD/20231101/VDLive_0250.xml
# ../data/raw/unzip_VD/20231101/VDLive_0251.xml
# ../data/raw/unzip_VD/20231101/VDLive_0252.xml
# ../data/raw/unzip_VD/20231101/VDLive_0253.xml
# ../data/raw/unzip_VD/20231101/VDLive_0254.xml
# ../data/raw/unzip_VD/20231101/VDLive_0255.xml
# ../data/raw/unzip_VD/20231101/VDLive_0256.xml
# ../data/raw/unzip_VD/20231101/VDLive_0257.xml
# ../data/raw/unzip_VD/20231101/VDLive_0258.xml
# ../data/raw/unzip_VD/20231101/VDLive_0259.xml
# ../data/raw/unzip_VD/20231101/VDLive_0300.xml
# ../data/raw/unzip_VD/20231101/VDLive_0301.xml
# ../data/raw/unzip_VD/20231101/VDLive_0302.xml
# ../data/raw/unzip_VD/20231101/VDLive_0303.xml
# ../data/raw/unzip_VD/20231101/VDLive_0304.xml
# ../data/raw/unzip_VD/20231101/VDLive_0305.xml
# ../data/raw/unzip_VD/20231101/VDLive_0306.xml
# ../data/raw/unzip_VD/20231101/VDLive_0307.xml
# ../data/raw/unzip_VD/20231101/VDLive_0308.xml
# ../data/raw/unzip_VD/20231101/VDLive_0309.xml
# ../data/raw/unzip_VD/20231101/VDLive_0310.xml
# ../data/raw/unzip_VD/20231101/VDLive_0311.xml
# ../data/raw/unzip_VD/20231101/VDLive_0312.xml
# ../data/raw/unzip_VD/20231101/VDLive_0313.xml
# ../data/raw/unzip_VD/20231101/VDLive_0314.xml
# ../data/raw/unzip_VD/20231101/VDLive_0315.xml
# ../data/raw/unzip_VD/20231101/VDLive_0316.xml
# ../data/raw/unzip_VD/20231101/VDLive_0317.xml
# ../data/raw/unzip_VD/20231101/VDLive_0318.xml
# ../data/raw/unzip_VD/20231101/VDLive_0319.xml
# ../data/raw/unzip_VD/20231101/VDLive_0320.xml
# ../data/raw/unzip_VD/20231101/VDLive_0321.xml
# ../data/raw/unzip_VD/20231101/VDLive_0322.xml
# ../data/raw/unzip_VD/20231101/VDLive_0323.xml
# ../data/raw/unzip_VD/20231101/VDLive_0324.xml
# ../data/raw/unzip_VD/20231101/VDLive_0325.xml
# ../data/raw/unzip_VD/20231101/VDLive_0326.xml
# ../data/raw/unzip_VD/20231101/VDLive_0327.xml
# ../data/raw/unzip_VD/20231101/VDLive_0328.xml
# ../data/raw/unzip_VD/20231101/VDLive_0329.xml
# ../data/raw/unzip_VD/20231101/VDLive_0330.xml
# ../data/raw/unzip_VD/20231101/VDLive_0331.xml
# ../data/raw/unzip_VD/20231101/VDLive_0332.xml
# ../data/raw/unzip_VD/20231101/VDLive_0333.xml
# ../data/raw/unzip_VD/20231101/VDLive_0334.xml
# ../data/raw/unzip_VD/20231101/VDLive_0335.xml
# ../data/raw/unzip_VD/20231101/VDLive_0336.xml
# ../data/raw/unzip_VD/20231101/VDLive_0337.xml
# ../data/raw/unzip_VD/20231101/VDLive_0338.xml
# ../data/raw/unzip_VD/20231101/VDLive_0339.xml
# ../data/raw/unzip_VD/20231101/VDLive_0340.xml
# ../data/raw/unzip_VD/20231101/VDLive_0341.xml
# ../data/raw/unzip_VD/20231101/VDLive_0342.xml
# ../data/raw/unzip_VD/20231101/VDLive_0343.xml
# ../data/raw/unzip_VD/20231101/VDLive_0344.xml
# ../data/raw/unzip_VD/20231101/VDLive_0345.xml
# ../data/raw/unzip_VD/20231101/VDLive_0346.xml
# ../data/raw/unzip_VD/20231101/VDLive_0347.xml
# ../data/raw/unzip_VD/20231101/VDLive_0348.xml
# ../data/raw/unzip_VD/20231101/VDLive_0349.xml
# ../data/raw/unzip_VD/20231101/VDLive_0350.xml
# ../data/raw/unzip_VD/20231101/VDLive_0351.xml
# ../data/raw/unzip_VD/20231101/VDLive_0352.xml
# ../data/raw/unzip_VD/20231101/VDLive_0353.xml
# ../data/raw/unzip_VD/20231101/VDLive_0354.xml
# ../data/raw/unzip_VD/20231101/VDLive_0355.xml
# ../data/raw/unzip_VD/20231101/VDLive_0356.xml
# ../data/raw/unzip_VD/20231101/VDLive_0357.xml
# ../data/raw/unzip_VD/20231101/VDLive_0358.xml
# ../data/raw/unzip_VD/20231101/VDLive_0359.xml
# ../data/raw/unzip_VD/20231101/VDLive_0400.xml
# ../data/raw/unzip_VD/20231101/VDLive_0401.xml
# ../data/raw/unzip_VD/20231101/VDLive_0402.xml
# ../data/raw/unzip_VD/20231101/VDLive_0403.xml
# ../data/raw/unzip_VD/20231101/VDLive_0404.xml
# ../data/raw/unzip_VD/20231101/VDLive_0405.xml
# ../data/raw/unzip_VD/20231101/VDLive_0406.xml
# ../data/raw/unzip_VD/20231101/VDLive_0407.xml
# ../data/raw/unzip_VD/20231101/VDLive_0408.xml
# ../data/raw/unzip_VD/20231101/VDLive_0409.xml
# ../data/raw/unzip_VD/20231101/VDLive_0410.xml
# ../data/raw/unzip_VD/20231101/VDLive_0411.xml
# ../data/raw/unzip_VD/20231101/VDLive_0412.xml
# ../data/raw/unzip_VD/20231101/VDLive_0413.xml
# ../data/raw/unzip_VD/20231101/VDLive_0414.xml
# ../data/raw/unzip_VD/20231101/VDLive_0415.xml
# ../data/raw/unzip_VD/20231101/VDLive_0416.xml
# ../data/raw/unzip_VD/20231101/VDLive_0417.xml
# ../data/raw/unzip_VD/20231101/VDLive_0418.xml
# ../data/raw/unzip_VD/20231101/VDLive_0419.xml
# ../data/raw/unzip_VD/20231101/VDLive_0420.xml
# ../data/raw/unzip_VD/20231101/VDLive_0421.xml
# ../data/raw/unzip_VD/20231101/VDLive_0422.xml
# ../data/raw/unzip_VD/20231101/VDLive_0423.xml
# ../data/raw/unzip_VD/20231101/VDLive_0424.xml
# ../data/raw/unzip_VD/20231101/VDLive_0425.xml
# ../data/raw/unzip_VD/20231101/VDLive_0426.xml
# ../data/raw/unzip_VD/20231101/VDLive_0427.xml
# ../data/raw/unzip_VD/20231101/VDLive_0428.xml
# ../data/raw/unzip_VD/20231101/VDLive_0429.xml
# ../data/raw/unzip_VD/20231101/VDLive_0430.xml
# ../data/raw/unzip_VD/20231101/VDLive_0431.xml
# ../data/raw/unzip_VD/20231101/VDLive_0432.xml
# ../data/raw/unzip_VD/20231101/VDLive_0433.xml
# ../data/raw/unzip_VD/20231101/VDLive_0434.xml
# ../data/raw/unzip_VD/20231101/VDLive_0435.xml
# ../data/raw/unzip_VD/20231101/VDLive_0436.xml
# ../data/raw/unzip_VD/20231101/VDLive_0437.xml
# ../data/raw/unzip_VD/20231101/VDLive_0438.xml
# ../data/raw/unzip_VD/20231101/VDLive_0439.xml
# ../data/raw/unzip_VD/20231101/VDLive_0440.xml
# ../data/raw/unzip_VD/20231101/VDLive_0441.xml
# ../data/raw/unzip_VD/20231101/VDLive_0442.xml
# ../data/raw/unzip_VD/20231101/VDLive_0443.xml
# ../data/raw/unzip_VD/20231101/VDLive_0444.xml
# ../data/raw/unzip_VD/20231101/VDLive_0445.xml
# ../data/raw/unzip_VD/20231101/VDLive_0446.xml
# ../data/raw/unzip_VD/20231101/VDLive_0447.xml
# ../data/raw/unzip_VD/20231101/VDLive_0448.xml
# ../data/raw/unzip_VD/20231101/VDLive_0449.xml
# ../data/raw/unzip_VD/20231101/VDLive_0450.xml
# ../data/raw/unzip_VD/20231101/VDLive_0451.xml
# ../data/raw/unzip_VD/20231101/VDLive_0452.xml
# ../data/raw/unzip_VD/20231101/VDLive_0453.xml
# ../data/raw/unzip_VD/20231101/VDLive_0454.xml
# ../data/raw/unzip_VD/20231101/VDLive_0455.xml
# ../data/raw/unzip_VD/20231101/VDLive_0456.xml
# ../data/raw/unzip_VD/20231101/VDLive_0457.xml
# ../data/raw/unzip_VD/20231101/VDLive_0458.xml
# ../data/raw/unzip_VD/20231101/VDLive_0459.xml
# ../data/raw/unzip_VD/20231101/VDLive_0500.xml
# ../data/raw/unzip_VD/20231101/VDLive_0501.xml
# ../data/raw/unzip_VD/20231101/VDLive_0502.xml
# ../data/raw/unzip_VD/20231101/VDLive_0503.xml
# ../data/raw/unzip_VD/20231101/VDLive_0504.xml
# ../data/raw/unzip_VD/20231101/VDLive_0505.xml
# ../data/raw/unzip_VD/20231101/VDLive_0506.xml
# ../data/raw/unzip_VD/20231101/VDLive_0507.xml
# ../data/raw/unzip_VD/20231101/VDLive_0508.xml
# ../data/raw/unzip_VD/20231101/VDLive_0509.xml
# ../data/raw/unzip_VD/20231101/VDLive_0510.xml
# ../data/raw/unzip_VD/20231101/VDLive_0511.xml
# ../data/raw/unzip_VD/20231101/VDLive_0512.xml
# ../data/raw/unzip_VD/20231101/VDLive_0513.xml
# ../data/raw/unzip_VD/20231101/VDLive_0514.xml
# ../data/raw/unzip_VD/20231101/VDLive_0515.xml
# ../data/raw/unzip_VD/20231101/VDLive_0516.xml
# ../data/raw/unzip_VD/20231101/VDLive_0517.xml
# ../data/raw/unzip_VD/20231101/VDLive_0518.xml
# ../data/raw/unzip_VD/20231101/VDLive_0519.xml
# ../data/raw/unzip_VD/20231101/VDLive_0520.xml
# ../data/raw/unzip_VD/20231101/VDLive_0521.xml
# ../data/raw/unzip_VD/20231101/VDLive_0522.xml
# ../data/raw/unzip_VD/20231101/VDLive_0523.xml
# ../data/raw/unzip_VD/20231101/VDLive_0524.xml
# ../data/raw/unzip_VD/20231101/VDLive_0525.xml
# ../data/raw/unzip_VD/20231101/VDLive_0526.xml
# ../data/raw/unzip_VD/20231101/VDLive_0527.xml
# ../data/raw/unzip_VD/20231101/VDLive_0528.xml
# ../data/raw/unzip_VD/20231101/VDLive_0529.xml
# ../data/raw/unzip_VD/20231101/VDLive_0530.xml
# ../data/raw/unzip_VD/20231101/VDLive_0531.xml
# ../data/raw/unzip_VD/20231101/VDLive_0532.xml
# ../data/raw/unzip_VD/20231101/VDLive_0533.xml
# ../data/raw/unzip_VD/20231101/VDLive_0534.xml
# ../data/raw/unzip_VD/20231101/VDLive_0535.xml
# ../data/raw/unzip_VD/20231101/VDLive_0536.xml
# ../data/raw/unzip_VD/20231101/VDLive_0537.xml
# ../data/raw/unzip_VD/20231101/VDLive_0538.xml
# ../data/raw/unzip_VD/20231101/VDLive_0539.xml
# ../data/raw/unzip_VD/20231101/VDLive_0540.xml
# ../data/raw/unzip_VD/20231101/VDLive_0541.xml
# ../data/raw/unzip_VD/20231101/VDLive_0542.xml
# ../data/raw/unzip_VD/20231101/VDLive_0543.xml
# ../data/raw/unzip_VD/20231101/VDLive_0544.xml
# ../data/raw/unzip_VD/20231101/VDLive_0545.xml
# ../data/raw/unzip_VD/20231101/VDLive_0546.xml
# ../data/raw/unzip_VD/20231101/VDLive_0547.xml
# ../data/raw/unzip_VD/20231101/VDLive_0548.xml
# ../data/raw/unzip_VD/20231101/VDLive_0549.xml
# ../data/raw/unzip_VD/20231101/VDLive_0550.xml
# ../data/raw/unzip_VD/20231101/VDLive_0551.xml
# ../data/raw/unzip_VD/20231101/VDLive_0552.xml
# ../data/raw/unzip_VD/20231101/VDLive_0553.xml
# ../data/raw/unzip_VD/20231101/VDLive_0554.xml
# ../data/raw/unzip_VD/20231101/VDLive_0555.xml
# ../data/raw/unzip_VD/20231101/VDLive_0556.xml
# ../data/raw/unzip_VD/20231101/VDLive_0557.xml
# ../data/raw/unzip_VD/20231101/VDLive_0558.xml
# ../data/raw/unzip_VD/20231101/VDLive_0559.xml
# ../data/raw/unzip_VD/20231101/VDLive_0600.xml
# ../data/raw/unzip_VD/20231101/VDLive_0601.xml
# ../data/raw/unzip_VD/20231101/VDLive_0602.xml
# ../data/raw/unzip_VD/20231101/VDLive_0603.xml
# ../data/raw/unzip_VD/20231101/VDLive_0604.xml
# ../data/raw/unzip_VD/20231101/VDLive_0605.xml
# ../data/raw/unzip_VD/20231101/VDLive_0606.xml
# ../data/raw/unzip_VD/20231101/VDLive_0607.xml
# ../data/raw/unzip_VD/20231101/VDLive_0608.xml
# ../data/raw/unzip_VD/20231101/VDLive_0609.xml
# ../data/raw/unzip_VD/20231101/VDLive_0610.xml
# ../data/raw/unzip_VD/20231101/VDLive_0611.xml
# ../data/raw/unzip_VD/20231101/VDLive_0612.xml
# ../data/raw/unzip_VD/20231101/VDLive_0613.xml
# ../data/raw/unzip_VD/20231101/VDLive_0614.xml
# ../data/raw/unzip_VD/20231101/VDLive_0615.xml
# ../data/raw/unzip_VD/20231101/VDLive_0616.xml
# ../data/raw/unzip_VD/20231101/VDLive_0617.xml
# ../data/raw/unzip_VD/20231101/VDLive_0618.xml
# ../data/raw/unzip_VD/20231101/VDLive_0619.xml
# ../data/raw/unzip_VD/20231101/VDLive_0620.xml
# ../data/raw/unzip_VD/20231101/VDLive_0621.xml
# ../data/raw/unzip_VD/20231101/VDLive_0622.xml
# ../data/raw/unzip_VD/20231101/VDLive_0623.xml
# ../data/raw/unzip_VD/20231101/VDLive_0624.xml
# ../data/raw/unzip_VD/20231101/VDLive_0625.xml
# ../data/raw/unzip_VD/20231101/VDLive_0626.xml
# ../data/raw/unzip_VD/20231101/VDLive_0627.xml
# ../data/raw/unzip_VD/20231101/VDLive_0628.xml
# ../data/raw/unzip_VD/20231101/VDLive_0629.xml
# ../data/raw/unzip_VD/20231101/VDLive_0630.xml
# ../data/raw/unzip_VD/20231101/VDLive_0631.xml
# ../data/raw/unzip_VD/20231101/VDLive_0632.xml
# ../data/raw/unzip_VD/20231101/VDLive_0633.xml
# ../data/raw/unzip_VD/20231101/VDLive_0634.xml
# ../data/raw/unzip_VD/20231101/VDLive_0635.xml
# ../data/raw/unzip_VD/20231101/VDLive_0636.xml
# ../data/raw/unzip_VD/20231101/VDLive_0637.xml
# ../data/raw/unzip_VD/20231101/VDLive_0638.xml
# ../data/raw/unzip_VD/20231101/VDLive_0639.xml
# ../data/raw/unzip_VD/20231101/VDLive_0640.xml
# ../data/raw/unzip_VD/20231101/VDLive_0641.xml
# ../data/raw/unzip_VD/20231101/VDLive_0642.xml
# ../data/raw/unzip_VD/20231101/VDLive_0643.xml
# ../data/raw/unzip_VD/20231101/VDLive_0644.xml
# ../data/raw/unzip_VD/20231101/VDLive_0645.xml
# ../data/raw/unzip_VD/20231101/VDLive_0646.xml
# ../data/raw/unzip_VD/20231101/VDLive_0647.xml
# ../data/raw/unzip_VD/20231101/VDLive_0648.xml
# ../data/raw/unzip_VD/20231101/VDLive_0649.xml
# ../data/raw/unzip_VD/20231101/VDLive_0650.xml
# ../data/raw/unzip_VD/20231101/VDLive_0651.xml
# ../data/raw/unzip_VD/20231101/VDLive_0652.xml
# ../data/raw/unzip_VD/20231101/VDLive_0653.xml
# ../data/raw/unzip_VD/20231101/VDLive_0654.xml
# ../data/raw/unzip_VD/20231101/VDLive_0655.xml
# ../data/raw/unzip_VD/20231101/VDLive_0656.xml
# ../data/raw/unzip_VD/20231101/VDLive_0657.xml
# ../data/raw/unzip_VD/20231101/VDLive_0658.xml
# ../data/raw/unzip_VD/20231101/VDLive_0659.xml
# ../data/raw/unzip_VD/20231101/VDLive_0700.xml
# ../data/raw/unzip_VD/20231101/VDLive_0701.xml
# ../data/raw/unzip_VD/20231101/VDLive_0702.xml
# ../data/raw/unzip_VD/20231101/VDLive_0703.xml
# ../data/raw/unzip_VD/20231101/VDLive_0704.xml
# ../data/raw/unzip_VD/20231101/VDLive_0705.xml
# ../data/raw/unzip_VD/20231101/VDLive_0706.xml
# ../data/raw/unzip_VD/20231101/VDLive_0707.xml
# ../data/raw/unzip_VD/20231101/VDLive_0708.xml
# ../data/raw/unzip_VD/20231101/VDLive_0709.xml
# ../data/raw/unzip_VD/20231101/VDLive_0710.xml
# ../data/raw/unzip_VD/20231101/VDLive_0711.xml
# ../data/raw/unzip_VD/20231101/VDLive_0712.xml
# ../data/raw/unzip_VD/20231101/VDLive_0713.xml
# ../data/raw/unzip_VD/20231101/VDLive_0714.xml
# ../data/raw/unzip_VD/20231101/VDLive_0715.xml
# ../data/raw/unzip_VD/20231101/VDLive_0716.xml
# ../data/raw/unzip_VD/20231101/VDLive_0717.xml
# ../data/raw/unzip_VD/20231101/VDLive_0718.xml
# ../data/raw/unzip_VD/20231101/VDLive_0719.xml
# ../data/raw/unzip_VD/20231101/VDLive_0720.xml
# ../data/raw/unzip_VD/20231101/VDLive_0721.xml
# ../data/raw/unzip_VD/20231101/VDLive_0722.xml
# ../data/raw/unzip_VD/20231101/VDLive_0723.xml
# ../data/raw/unzip_VD/20231101/VDLive_0724.xml
# ../data/raw/unzip_VD/20231101/VDLive_0725.xml
# ../data/raw/unzip_VD/20231101/VDLive_0726.xml
# ../data/raw/unzip_VD/20231101/VDLive_0727.xml
# ../data/raw/unzip_VD/20231101/VDLive_0728.xml
# ../data/raw/unzip_VD/20231101/VDLive_0729.xml
# ../data/raw/unzip_VD/20231101/VDLive_0730.xml
# ../data/raw/unzip_VD/20231101/VDLive_0731.xml
# ../data/raw/unzip_VD/20231101/VDLive_0732.xml
# ../data/raw/unzip_VD/20231101/VDLive_0733.xml
# ../data/raw/unzip_VD/20231101/VDLive_0734.xml
# ../data/raw/unzip_VD/20231101/VDLive_0735.xml
# ../data/raw/unzip_VD/20231101/VDLive_0736.xml
# ../data/raw/unzip_VD/20231101/VDLive_0737.xml
# ../data/raw/unzip_VD/20231101/VDLive_0738.xml
# ../data/raw/unzip_VD/20231101/VDLive_0739.xml
# ../data/raw/unzip_VD/20231101/VDLive_0740.xml
# ../data/raw/unzip_VD/20231101/VDLive_0741.xml
# ../data/raw/unzip_VD/20231101/VDLive_0742.xml
# ../data/raw/unzip_VD/20231101/VDLive_0743.xml
# ../data/raw/unzip_VD/20231101/VDLive_0744.xml
# ../data/raw/unzip_VD/20231101/VDLive_0745.xml
# ../data/raw/unzip_VD/20231101/VDLive_0746.xml
# ../data/raw/unzip_VD/20231101/VDLive_0747.xml
# ../data/raw/unzip_VD/20231101/VDLive_0748.xml
# ../data/raw/unzip_VD/20231101/VDLive_0749.xml
# ../data/raw/unzip_VD/20231101/VDLive_0750.xml
# ../data/raw/unzip_VD/20231101/VDLive_0751.xml
# ../data/raw/unzip_VD/20231101/VDLive_0752.xml
# ../data/raw/unzip_VD/20231101/VDLive_0753.xml
# ../data/raw/unzip_VD/20231101/VDLive_0754.xml
# ../data/raw/unzip_VD/20231101/VDLive_0755.xml
# ../data/raw/unzip_VD/20231101/VDLive_0756.xml
# ../data/raw/unzip_VD/20231101/VDLive_0757.xml
# ../data/raw/unzip_VD/20231101/VDLive_0758.xml
# ../data/raw/unzip_VD/20231101/VDLive_0759.xml
# ../data/raw/unzip_VD/20231101/VDLive_0800.xml
# ../data/raw/unzip_VD/20231101/VDLive_0801.xml
# ../data/raw/unzip_VD/20231101/VDLive_0802.xml
# ../data/raw/unzip_VD/20231101/VDLive_0803.xml
# ../data/raw/unzip_VD/20231101/VDLive_0804.xml
# ../data/raw/unzip_VD/20231101/VDLive_0805.xml
# ../data/raw/unzip_VD/20231101/VDLive_0806.xml
# ../data/raw/unzip_VD/20231101/VDLive_0807.xml
# ../data/raw/unzip_VD/20231101/VDLive_0808.xml
# ../data/raw/unzip_VD/20231101/VDLive_0809.xml
# ../data/raw/unzip_VD/20231101/VDLive_0810.xml
# ../data/raw/unzip_VD/20231101/VDLive_0811.xml
# ../data/raw/unzip_VD/20231101/VDLive_0812.xml
# ../data/raw/unzip_VD/20231101/VDLive_0813.xml
# ../data/raw/unzip_VD/20231101/VDLive_0814.xml
# ../data/raw/unzip_VD/20231101/VDLive_0815.xml
# ../data/raw/unzip_VD/20231101/VDLive_0816.xml
# ../data/raw/unzip_VD/20231101/VDLive_0817.xml
# ../data/raw/unzip_VD/20231101/VDLive_0818.xml
# ../data/raw/unzip_VD/20231101/VDLive_0819.xml
# ../data/raw/unzip_VD/20231101/VDLive_0820.xml
# ../data/raw/unzip_VD/20231101/VDLive_0821.xml
# ../data/raw/unzip_VD/20231101/VDLive_0822.xml
# ../data/raw/unzip_VD/20231101/VDLive_0823.xml
# ../data/raw/unzip_VD/20231101/VDLive_0824.xml
# ../data/raw/unzip_VD/20231101/VDLive_0825.xml
# ../data/raw/unzip_VD/20231101/VDLive_0826.xml
# ../data/raw/unzip_VD/20231101/VDLive_0827.xml
# ../data/raw/unzip_VD/20231101/VDLive_0828.xml
# ../data/raw/unzip_VD/20231101/VDLive_0829.xml
# ../data/raw/unzip_VD/20231101/VDLive_0830.xml
# ../data/raw/unzip_VD/20231101/VDLive_0831.xml
# ../data/raw/unzip_VD/20231101/VDLive_0832.xml
# ../data/raw/unzip_VD/20231101/VDLive_0833.xml
# ../data/raw/unzip_VD/20231101/VDLive_0834.xml
# ../data/raw/unzip_VD/20231101/VDLive_0835.xml
# ../data/raw/unzip_VD/20231101/VDLive_0836.xml
# ../data/raw/unzip_VD/20231101/VDLive_0837.xml
# ../data/raw/unzip_VD/20231101/VDLive_0838.xml
# ../data/raw/unzip_VD/20231101/VDLive_0839.xml
# ../data/raw/unzip_VD/20231101/VDLive_0840.xml
# ../data/raw/unzip_VD/20231101/VDLive_0841.xml
# ../data/raw/unzip_VD/20231101/VDLive_0842.xml
# ../data/raw/unzip_VD/20231101/VDLive_0843.xml
# ../data/raw/unzip_VD/20231101/VDLive_0844.xml
# ../data/raw/unzip_VD/20231101/VDLive_0845.xml
# ../data/raw/unzip_VD/20231101/VDLive_0846.xml
# ../data/raw/unzip_VD/20231101/VDLive_0847.xml
# ../data/raw/unzip_VD/20231101/VDLive_0848.xml
# ../data/raw/unzip_VD/20231101/VDLive_0849.xml
# ../data/raw/unzip_VD/20231101/VDLive_0850.xml
# ../data/raw/unzip_VD/20231101/VDLive_0851.xml
# ../data/raw/unzip_VD/20231101/VDLive_0852.xml
# ../data/raw/unzip_VD/20231101/VDLive_0853.xml
# ../data/raw/unzip_VD/20231101/VDLive_0854.xml
# ../data/raw/unzip_VD/20231101/VDLive_0855.xml
# ../data/raw/unzip_VD/20231101/VDLive_0856.xml
# ../data/raw/unzip_VD/20231101/VDLive_0857.xml
# ../data/raw/unzip_VD/20231101/VDLive_0858.xml
# ../data/raw/unzip_VD/20231101/VDLive_0859.xml
# ../data/raw/unzip_VD/20231101/VDLive_0900.xml
# ../data/raw/unzip_VD/20231101/VDLive_0901.xml
# ../data/raw/unzip_VD/20231101/VDLive_0902.xml
# ../data/raw/unzip_VD/20231101/VDLive_0903.xml
# ../data/raw/unzip_VD/20231101/VDLive_0904.xml
# ../data/raw/unzip_VD/20231101/VDLive_0905.xml
# ../data/raw/unzip_VD/20231101/VDLive_0906.xml
# ../data/raw/unzip_VD/20231101/VDLive_0907.xml
# ../data/raw/unzip_VD/20231101/VDLive_0908.xml
# ../data/raw/unzip_VD/20231101/VDLive_0909.xml
# ../data/raw/unzip_VD/20231101/VDLive_0910.xml
# ../data/raw/unzip_VD/20231101/VDLive_0911.xml
# ../data/raw/unzip_VD/20231101/VDLive_0912.xml
# ../data/raw/unzip_VD/20231101/VDLive_0913.xml
# ../data/raw/unzip_VD/20231101/VDLive_0914.xml
# ../data/raw/unzip_VD/20231101/VDLive_0915.xml
# ../data/raw/unzip_VD/20231101/VDLive_0916.xml
# ../data/raw/unzip_VD/20231101/VDLive_0917.xml
# ../data/raw/unzip_VD/20231101/VDLive_0918.xml
# ../data/raw/unzip_VD/20231101/VDLive_0919.xml
# ../data/raw/unzip_VD/20231101/VDLive_0920.xml
# ../data/raw/unzip_VD/20231101/VDLive_0921.xml
# ../data/raw/unzip_VD/20231101/VDLive_0922.xml
# ../data/raw/unzip_VD/20231101/VDLive_0923.xml
# ../data/raw/unzip_VD/20231101/VDLive_0924.xml
# ../data/raw/unzip_VD/20231101/VDLive_0925.xml
# ../data/raw/unzip_VD/20231101/VDLive_0926.xml
# ../data/raw/unzip_VD/20231101/VDLive_0927.xml
# ../data/raw/unzip_VD/20231101/VDLive_0928.xml
# ../data/raw/unzip_VD/20231101/VDLive_0929.xml
# ../data/raw/unzip_VD/20231101/VDLive_0930.xml
# ../data/raw/unzip_VD/20231101/VDLive_0931.xml
# ../data/raw/unzip_VD/20231101/VDLive_0932.xml
# ../data/raw/unzip_VD/20231101/VDLive_0933.xml
# ../data/raw/unzip_VD/20231101/VDLive_0934.xml
# ../data/raw/unzip_VD/20231101/VDLive_0935.xml
# ../data/raw/unzip_VD/20231101/VDLive_0936.xml
# ../data/raw/unzip_VD/20231101/VDLive_0937.xml
# ../data/raw/unzip_VD/20231101/VDLive_0938.xml
# ../data/raw/unzip_VD/20231101/VDLive_0939.xml
# ../data/raw/unzip_VD/20231101/VDLive_0940.xml
# ../data/raw/unzip_VD/20231101/VDLive_0941.xml
# ../data/raw/unzip_VD/20231101/VDLive_0942.xml
# ../data/raw/unzip_VD/20231101/VDLive_0943.xml
# ../data/raw/unzip_VD/20231101/VDLive_0944.xml
# ../data/raw/unzip_VD/20231101/VDLive_0945.xml
# ../data/raw/unzip_VD/20231101/VDLive_0946.xml
# ../data/raw/unzip_VD/20231101/VDLive_0947.xml
# ../data/raw/unzip_VD/20231101/VDLive_0948.xml
# ../data/raw/unzip_VD/20231101/VDLive_0949.xml
# ../data/raw/unzip_VD/20231101/VDLive_0950.xml
# ../data/raw/unzip_VD/20231101/VDLive_0951.xml
# ../data/raw/unzip_VD/20231101/VDLive_0952.xml
# ../data/raw/unzip_VD/20231101/VDLive_0953.xml
# ../data/raw/unzip_VD/20231101/VDLive_0954.xml
# ../data/raw/unzip_VD/20231101/VDLive_0955.xml
# ../data/raw/unzip_VD/20231101/VDLive_0956.xml
# ../data/raw/unzip_VD/20231101/VDLive_0957.xml
# ../data/raw/unzip_VD/20231101/VDLive_0958.xml
# ../data/raw/unzip_VD/20231101/VDLive_0959.xml
# ../data/raw/unzip_VD/20231101/VDLive_1000.xml
# ../data/raw/unzip_VD/20231101/VDLive_1001.xml
# ../data/raw/unzip_VD/20231101/VDLive_1002.xml
# ../data/raw/unzip_VD/20231101/VDLive_1003.xml
# ../data/raw/unzip_VD/20231101/VDLive_1004.xml
# ../data/raw/unzip_VD/20231101/VDLive_1005.xml
# ../data/raw/unzip_VD/20231101/VDLive_1006.xml
# ../data/raw/unzip_VD/20231101/VDLive_1007.xml
# ../data/raw/unzip_VD/20231101/VDLive_1008.xml
# ../data/raw/unzip_VD/20231101/VDLive_1009.xml
# ../data/raw/unzip_VD/20231101/VDLive_1010.xml
# ../data/raw/unzip_VD/20231101/VDLive_1011.xml
# ../data/raw/unzip_VD/20231101/VDLive_1012.xml
# ../data/raw/unzip_VD/20231101/VDLive_1013.xml
# ../data/raw/unzip_VD/20231101/VDLive_1014.xml
# ../data/raw/unzip_VD/20231101/VDLive_1015.xml
# ../data/raw/unzip_VD/20231101/VDLive_1016.xml
# ../data/raw/unzip_VD/20231101/VDLive_1017.xml
# ../data/raw/unzip_VD/20231101/VDLive_1018.xml
# ../data/raw/unzip_VD/20231101/VDLive_1019.xml
# ../data/raw/unzip_VD/20231101/VDLive_1020.xml
# ../data/raw/unzip_VD/20231101/VDLive_1021.xml
# ../data/raw/unzip_VD/20231101/VDLive_1022.xml
# ../data/raw/unzip_VD/20231101/VDLive_1023.xml
# ../data/raw/unzip_VD/20231101/VDLive_1024.xml
# ../data/raw/unzip_VD/20231101/VDLive_1025.xml
# ../data/raw/unzip_VD/20231101/VDLive_1026.xml
# ../data/raw/unzip_VD/20231101/VDLive_1027.xml
# ../data/raw/unzip_VD/20231101/VDLive_1028.xml
# ../data/raw/unzip_VD/20231101/VDLive_1029.xml
# ../data/raw/unzip_VD/20231101/VDLive_1030.xml
# ../data/raw/unzip_VD/20231101/VDLive_1031.xml
# ../data/raw/unzip_VD/20231101/VDLive_1032.xml
# ../data/raw/unzip_VD/20231101/VDLive_1033.xml
# ../data/raw/unzip_VD/20231101/VDLive_1034.xml
# ../data/raw/unzip_VD/20231101/VDLive_1035.xml
# ../data/raw/unzip_VD/20231101/VDLive_1036.xml
# ../data/raw/unzip_VD/20231101/VDLive_1037.xml
# ../data/raw/unzip_VD/20231101/VDLive_1038.xml
# ../data/raw/unzip_VD/20231101/VDLive_1039.xml
# ../data/raw/unzip_VD/20231101/VDLive_1040.xml
# ../data/raw/unzip_VD/20231101/VDLive_1041.xml
# ../data/raw/unzip_VD/20231101/VDLive_1042.xml
# ../data/raw/unzip_VD/20231101/VDLive_1043.xml
# ../data/raw/unzip_VD/20231101/VDLive_1044.xml
# ../data/raw/unzip_VD/20231101/VDLive_1045.xml
# ../data/raw/unzip_VD/20231101/VDLive_1046.xml
# ../data/raw/unzip_VD/20231101/VDLive_1047.xml
# ../data/raw/unzip_VD/20231101/VDLive_1048.xml
# ../data/raw/unzip_VD/20231101/VDLive_1049.xml
# ../data/raw/unzip_VD/20231101/VDLive_1050.xml
# ../data/raw/unzip_VD/20231101/VDLive_1051.xml
# ../data/raw/unzip_VD/20231101/VDLive_1052.xml
# ../data/raw/unzip_VD/20231101/VDLive_1053.xml
# ../data/raw/unzip_VD/20231101/VDLive_1054.xml
# ../data/raw/unzip_VD/20231101/VDLive_1055.xml
# ../data/raw/unzip_VD/20231101/VDLive_1056.xml
# ../data/raw/unzip_VD/20231101/VDLive_1057.xml
# ../data/raw/unzip_VD/20231101/VDLive_1058.xml
# ../data/raw/unzip_VD/20231101/VDLive_1059.xml
# ../data/raw/unzip_VD/20231101/VDLive_1100.xml
# ../data/raw/unzip_VD/20231101/VDLive_1101.xml
# ../data/raw/unzip_VD/20231101/VDLive_1102.xml
# ../data/raw/unzip_VD/20231101/VDLive_1103.xml
# ../data/raw/unzip_VD/20231101/VDLive_1104.xml
# ../data/raw/unzip_VD/20231101/VDLive_1105.xml
# ../data/raw/unzip_VD/20231101/VDLive_1106.xml
# ../data/raw/unzip_VD/20231101/VDLive_1107.xml
# ../data/raw/unzip_VD/20231101/VDLive_1108.xml
# ../data/raw/unzip_VD/20231101/VDLive_1109.xml
# ../data/raw/unzip_VD/20231101/VDLive_1110.xml
# ../data/raw/unzip_VD/20231101/VDLive_1111.xml
# ../data/raw/unzip_VD/20231101/VDLive_1112.xml
# ../data/raw/unzip_VD/20231101/VDLive_1113.xml
# ../data/raw/unzip_VD/20231101/VDLive_1114.xml
# ../data/raw/unzip_VD/20231101/VDLive_1115.xml
# ../data/raw/unzip_VD/20231101/VDLive_1116.xml
# ../data/raw/unzip_VD/20231101/VDLive_1117.xml
# ../data/raw/unzip_VD/20231101/VDLive_1118.xml
# ../data/raw/unzip_VD/20231101/VDLive_1119.xml
# ../data/raw/unzip_VD/20231101/VDLive_1120.xml
# ../data/raw/unzip_VD/20231101/VDLive_1121.xml
# ../data/raw/unzip_VD/20231101/VDLive_1122.xml
# ../data/raw/unzip_VD/20231101/VDLive_1123.xml
# ../data/raw/unzip_VD/20231101/VDLive_1124.xml
# ../data/raw/unzip_VD/20231101/VDLive_1125.xml
# ../data/raw/unzip_VD/20231101/VDLive_1126.xml
# ../data/raw/unzip_VD/20231101/VDLive_1127.xml
# ../data/raw/unzip_VD/20231101/VDLive_1128.xml
# ../data/raw/unzip_VD/20231101/VDLive_1129.xml
# ../data/raw/unzip_VD/20231101/VDLive_1130.xml
# ../data/raw/unzip_VD/20231101/VDLive_1131.xml
# ../data/raw/unzip_VD/20231101/VDLive_1132.xml
# ../data/raw/unzip_VD/20231101/VDLive_1133.xml
# ../data/raw/unzip_VD/20231101/VDLive_1134.xml
# ../data/raw/unzip_VD/20231101/VDLive_1135.xml
# ../data/raw/unzip_VD/20231101/VDLive_1136.xml
# ../data/raw/unzip_VD/20231101/VDLive_1137.xml
# ../data/raw/unzip_VD/20231101/VDLive_1138.xml
# ../data/raw/unzip_VD/20231101/VDLive_1139.xml
# ../data/raw/unzip_VD/20231101/VDLive_1140.xml
# ../data/raw/unzip_VD/20231101/VDLive_1141.xml
# ../data/raw/unzip_VD/20231101/VDLive_1142.xml
# ../data/raw/unzip_VD/20231101/VDLive_1143.xml
# ../data/raw/unzip_VD/20231101/VDLive_1144.xml
# ../data/raw/unzip_VD/20231101/VDLive_1145.xml
# ../data/raw/unzip_VD/20231101/VDLive_1146.xml
# ../data/raw/unzip_VD/20231101/VDLive_1147.xml
# ../data/raw/unzip_VD/20231101/VDLive_1148.xml
# ../data/raw/unzip_VD/20231101/VDLive_1149.xml
# ../data/raw/unzip_VD/20231101/VDLive_1150.xml
# ../data/raw/unzip_VD/20231101/VDLive_1151.xml
# ../data/raw/unzip_VD/20231101/VDLive_1152.xml
# ../data/raw/unzip_VD/20231101/VDLive_1153.xml
# ../data/raw/unzip_VD/20231101/VDLive_1154.xml
# ../data/raw/unzip_VD/20231101/VDLive_1155.xml
# ../data/raw/unzip_VD/20231101/VDLive_1156.xml
# ../data/raw/unzip_VD/20231101/VDLive_1157.xml
# ../data/raw/unzip_VD/20231101/VDLive_1158.xml
# ../data/raw/unzip_VD/20231101/VDLive_1159.xml
# ../data/raw/unzip_VD/20231101/VDLive_1200.xml
# ../data/raw/unzip_VD/20231101/VDLive_1201.xml
# ../data/raw/unzip_VD/20231101/VDLive_1202.xml
# ../data/raw/unzip_VD/20231101/VDLive_1203.xml
# ../data/raw/unzip_VD/20231101/VDLive_1204.xml
# ../data/raw/unzip_VD/20231101/VDLive_1205.xml
# ../data/raw/unzip_VD/20231101/VDLive_1206.xml
# ../data/raw/unzip_VD/20231101/VDLive_1207.xml
# ../data/raw/unzip_VD/20231101/VDLive_1208.xml
# ../data/raw/unzip_VD/20231101/VDLive_1209.xml
# ../data/raw/unzip_VD/20231101/VDLive_1210.xml
# ../data/raw/unzip_VD/20231101/VDLive_1211.xml
# ../data/raw/unzip_VD/20231101/VDLive_1212.xml
# ../data/raw/unzip_VD/20231101/VDLive_1213.xml
# ../data/raw/unzip_VD/20231101/VDLive_1214.xml
# ../data/raw/unzip_VD/20231101/VDLive_1215.xml
# ../data/raw/unzip_VD/20231101/VDLive_1216.xml
# ../data/raw/unzip_VD/20231101/VDLive_1217.xml
# ../data/raw/unzip_VD/20231101/VDLive_1218.xml
# ../data/raw/unzip_VD/20231101/VDLive_1219.xml
# ../data/raw/unzip_VD/20231101/VDLive_1220.xml
# ../data/raw/unzip_VD/20231101/VDLive_1221.xml
# ../data/raw/unzip_VD/20231101/VDLive_1222.xml
# ../data/raw/unzip_VD/20231101/VDLive_1223.xml
# ../data/raw/unzip_VD/20231101/VDLive_1224.xml
# ../data/raw/unzip_VD/20231101/VDLive_1225.xml
# ../data/raw/unzip_VD/20231101/VDLive_1226.xml
# ../data/raw/unzip_VD/20231101/VDLive_1227.xml
# ../data/raw/unzip_VD/20231101/VDLive_1228.xml
# ../data/raw/unzip_VD/20231101/VDLive_1229.xml
# ../data/raw/unzip_VD/20231101/VDLive_1230.xml
# ../data/raw/unzip_VD/20231101/VDLive_1231.xml
# ../data/raw/unzip_VD/20231101/VDLive_1232.xml
# ../data/raw/unzip_VD/20231101/VDLive_1233.xml
# ../data/raw/unzip_VD/20231101/VDLive_1234.xml
# ../data/raw/unzip_VD/20231101/VDLive_1235.xml
# ../data/raw/unzip_VD/20231101/VDLive_1236.xml
# ../data/raw/unzip_VD/20231101/VDLive_1237.xml
# ../data/raw/unzip_VD/20231101/VDLive_1238.xml
# ../data/raw/unzip_VD/20231101/VDLive_1239.xml
# ../data/raw/unzip_VD/20231101/VDLive_1240.xml
# ../data/raw/unzip_VD/20231101/VDLive_1241.xml
# ../data/raw/unzip_VD/20231101/VDLive_1242.xml
# ../data/raw/unzip_VD/20231101/VDLive_1243.xml
# ../data/raw/unzip_VD/20231101/VDLive_1244.xml
# ../data/raw/unzip_VD/20231101/VDLive_1245.xml
# ../data/raw/unzip_VD/20231101/VDLive_1246.xml
# ../data/raw/unzip_VD/20231101/VDLive_1247.xml
# ../data/raw/unzip_VD/20231101/VDLive_1248.xml
# ../data/raw/unzip_VD/20231101/VDLive_1249.xml
# ../data/raw/unzip_VD/20231101/VDLive_1250.xml
# ../data/raw/unzip_VD/20231101/VDLive_1251.xml
# ../data/raw/unzip_VD/20231101/VDLive_1252.xml
# ../data/raw/unzip_VD/20231101/VDLive_1253.xml
# ../data/raw/unzip_VD/20231101/VDLive_1254.xml
# ../data/raw/unzip_VD/20231101/VDLive_1255.xml
# ../data/raw/unzip_VD/20231101/VDLive_1256.xml
# ../data/raw/unzip_VD/20231101/VDLive_1257.xml
# ../data/raw/unzip_VD/20231101/VDLive_1258.xml
# ../data/raw/unzip_VD/20231101/VDLive_1259.xml
# ../data/raw/unzip_VD/20231101/VDLive_1300.xml
# ../data/raw/unzip_VD/20231101/VDLive_1301.xml
# ../data/raw/unzip_VD/20231101/VDLive_1302.xml
# ../data/raw/unzip_VD/20231101/VDLive_1303.xml
# ../data/raw/unzip_VD/20231101/VDLive_1304.xml
# ../data/raw/unzip_VD/20231101/VDLive_1305.xml
# ../data/raw/unzip_VD/20231101/VDLive_1306.xml
# ../data/raw/unzip_VD/20231101/VDLive_1307.xml
# ../data/raw/unzip_VD/20231101/VDLive_1308.xml
# ../data/raw/unzip_VD/20231101/VDLive_1309.xml
# ../data/raw/unzip_VD/20231101/VDLive_1310.xml
# ../data/raw/unzip_VD/20231101/VDLive_1311.xml
# ../data/raw/unzip_VD/20231101/VDLive_1312.xml
# ../data/raw/unzip_VD/20231101/VDLive_1313.xml
# ../data/raw/unzip_VD/20231101/VDLive_1314.xml
# ../data/raw/unzip_VD/20231101/VDLive_1315.xml
# ../data/raw/unzip_VD/20231101/VDLive_1316.xml
# ../data/raw/unzip_VD/20231101/VDLive_1317.xml
# ../data/raw/unzip_VD/20231101/VDLive_1318.xml
# ../data/raw/unzip_VD/20231101/VDLive_1319.xml
# ../data/raw/unzip_VD/20231101/VDLive_1320.xml
# ../data/raw/unzip_VD/20231101/VDLive_1321.xml
# ../data/raw/unzip_VD/20231101/VDLive_1322.xml
# ../data/raw/unzip_VD/20231101/VDLive_1323.xml
# ../data/raw/unzip_VD/20231101/VDLive_1324.xml
# ../data/raw/unzip_VD/20231101/VDLive_1325.xml
# ../data/raw/unzip_VD/20231101/VDLive_1326.xml
# ../data/raw/unzip_VD/20231101/VDLive_1327.xml
# ../data/raw/unzip_VD/20231101/VDLive_1328.xml
# ../data/raw/unzip_VD/20231101/VDLive_1329.xml
# ../data/raw/unzip_VD/20231101/VDLive_1330.xml
# ../data/raw/unzip_VD/20231101/VDLive_1331.xml
# ../data/raw/unzip_VD/20231101/VDLive_1332.xml
# ../data/raw/unzip_VD/20231101/VDLive_1333.xml
# ../data/raw/unzip_VD/20231101/VDLive_1334.xml
# ../data/raw/unzip_VD/20231101/VDLive_1335.xml
# ../data/raw/unzip_VD/20231101/VDLive_1336.xml
# ../data/raw/unzip_VD/20231101/VDLive_1337.xml
# ../data/raw/unzip_VD/20231101/VDLive_1338.xml
# ../data/raw/unzip_VD/20231101/VDLive_1339.xml
# ../data/raw/unzip_VD/20231101/VDLive_1340.xml
# ../data/raw/unzip_VD/20231101/VDLive_1341.xml
# ../data/raw/unzip_VD/20231101/VDLive_1342.xml
# ../data/raw/unzip_VD/20231101/VDLive_1343.xml
# ../data/raw/unzip_VD/20231101/VDLive_1344.xml
# ../data/raw/unzip_VD/20231101/VDLive_1345.xml
# ../data/raw/unzip_VD/20231101/VDLive_1346.xml
# ../data/raw/unzip_VD/20231101/VDLive_1347.xml
# ../data/raw/unzip_VD/20231101/VDLive_1348.xml
# ../data/raw/unzip_VD/20231101/VDLive_1349.xml
# ../data/raw/unzip_VD/20231101/VDLive_1350.xml
# ../data/raw/unzip_VD/20231101/VDLive_1351.xml
# ../data/raw/unzip_VD/20231101/VDLive_1352.xml
# ../data/raw/unzip_VD/20231101/VDLive_1353.xml
# ../data/raw/unzip_VD/20231101/VDLive_1354.xml
# ../data/raw/unzip_VD/20231101/VDLive_1355.xml
# ../data/raw/unzip_VD/20231101/VDLive_1356.xml
# ../data/raw/unzip_VD/20231101/VDLive_1357.xml
# ../data/raw/unzip_VD/20231101/VDLive_1358.xml
# ../data/raw/unzip_VD/20231101/VDLive_1359.xml
# ../data/raw/unzip_VD/20231101/VDLive_1400.xml
# ../data/raw/unzip_VD/20231101/VDLive_1401.xml
# ../data/raw/unzip_VD/20231101/VDLive_1402.xml
# ../data/raw/unzip_VD/20231101/VDLive_1403.xml
# ../data/raw/unzip_VD/20231101/VDLive_1404.xml
# ../data/raw/unzip_VD/20231101/VDLive_1405.xml
# ../data/raw/unzip_VD/20231101/VDLive_1406.xml
# ../data/raw/unzip_VD/20231101/VDLive_1407.xml
# ../data/raw/unzip_VD/20231101/VDLive_1408.xml
# ../data/raw/unzip_VD/20231101/VDLive_1409.xml
# ../data/raw/unzip_VD/20231101/VDLive_1410.xml
# ../data/raw/unzip_VD/20231101/VDLive_1411.xml
# ../data/raw/unzip_VD/20231101/VDLive_1412.xml
# ../data/raw/unzip_VD/20231101/VDLive_1413.xml
# ../data/raw/unzip_VD/20231101/VDLive_1414.xml
# ../data/raw/unzip_VD/20231101/VDLive_1415.xml
# ../data/raw/unzip_VD/20231101/VDLive_1416.xml
# ../data/raw/unzip_VD/20231101/VDLive_1417.xml
# ../data/raw/unzip_VD/20231101/VDLive_1418.xml
# ../data/raw/unzip_VD/20231101/VDLive_1419.xml
# ../data/raw/unzip_VD/20231101/VDLive_1420.xml
# ../data/raw/unzip_VD/20231101/VDLive_1421.xml
# ../data/raw/unzip_VD/20231101/VDLive_1422.xml
# ../data/raw/unzip_VD/20231101/VDLive_1423.xml
# ../data/raw/unzip_VD/20231101/VDLive_1424.xml
# ../data/raw/unzip_VD/20231101/VDLive_1425.xml
# ../data/raw/unzip_VD/20231101/VDLive_1426.xml
# ../data/raw/unzip_VD/20231101/VDLive_1427.xml
# ../data/raw/unzip_VD/20231101/VDLive_1428.xml
# ../data/raw/unzip_VD/20231101/VDLive_1429.xml
# ../data/raw/unzip_VD/20231101/VDLive_1430.xml
# ../data/raw/unzip_VD/20231101/VDLive_1431.xml
# ../data/raw/unzip_VD/20231101/VDLive_1432.xml
# ../data/raw/unzip_VD/20231101/VDLive_1433.xml
# ../data/raw/unzip_VD/20231101/VDLive_1434.xml
# ../data/raw/unzip_VD/20231101/VDLive_1435.xml
# ../data/raw/unzip_VD/20231101/VDLive_1436.xml
# ../data/raw/unzip_VD/20231101/VDLive_1437.xml
# ../data/raw/unzip_VD/20231101/VDLive_1438.xml
# ../data/raw/unzip_VD/20231101/VDLive_1439.xml
# ../data/raw/unzip_VD/20231101/VDLive_1440.xml
# ../data/raw/unzip_VD/20231101/VDLive_1441.xml
# ../data/raw/unzip_VD/20231101/VDLive_1442.xml
# ../data/raw/unzip_VD/20231101/VDLive_1443.xml
# ../data/raw/unzip_VD/20231101/VDLive_1444.xml
# ../data/raw/unzip_VD/20231101/VDLive_1445.xml
# ../data/raw/unzip_VD/20231101/VDLive_1446.xml
# ../data/raw/unzip_VD/20231101/VDLive_1447.xml
# ../data/raw/unzip_VD/20231101/VDLive_1448.xml
# ../data/raw/unzip_VD/20231101/VDLive_1449.xml
# ../data/raw/unzip_VD/20231101/VDLive_1450.xml
# ../data/raw/unzip_VD/20231101/VDLive_1451.xml
# ../data/raw/unzip_VD/20231101/VDLive_1452.xml
# ../data/raw/unzip_VD/20231101/VDLive_1453.xml
# ../data/raw/unzip_VD/20231101/VDLive_1454.xml
# ../data/raw/unzip_VD/20231101/VDLive_1455.xml
# ../data/raw/unzip_VD/20231101/VDLive_1456.xml
# ../data/raw/unzip_VD/20231101/VDLive_1457.xml
# ../data/raw/unzip_VD/20231101/VDLive_1458.xml
# ../data/raw/unzip_VD/20231101/VDLive_1459.xml
# ../data/raw/unzip_VD/20231101/VDLive_1500.xml
# ../data/raw/unzip_VD/20231101/VDLive_1501.xml
# ../data/raw/unzip_VD/20231101/VDLive_1502.xml
# ../data/raw/unzip_VD/20231101/VDLive_1503.xml
# ../data/raw/unzip_VD/20231101/VDLive_1504.xml
# ../data/raw/unzip_VD/20231101/VDLive_1505.xml
# ../data/raw/unzip_VD/20231101/VDLive_1506.xml
# ../data/raw/unzip_VD/20231101/VDLive_1507.xml
# ../data/raw/unzip_VD/20231101/VDLive_1508.xml
# ../data/raw/unzip_VD/20231101/VDLive_1509.xml
# ../data/raw/unzip_VD/20231101/VDLive_1510.xml
# ../data/raw/unzip_VD/20231101/VDLive_1511.xml
# ../data/raw/unzip_VD/20231101/VDLive_1512.xml
# ../data/raw/unzip_VD/20231101/VDLive_1513.xml
# ../data/raw/unzip_VD/20231101/VDLive_1514.xml
# ../data/raw/unzip_VD/20231101/VDLive_1515.xml
# ../data/raw/unzip_VD/20231101/VDLive_1516.xml
# ../data/raw/unzip_VD/20231101/VDLive_1517.xml
# ../data/raw/unzip_VD/20231101/VDLive_1518.xml
# ../data/raw/unzip_VD/20231101/VDLive_1519.xml
# ../data/raw/unzip_VD/20231101/VDLive_1520.xml
# ../data/raw/unzip_VD/20231101/VDLive_1521.xml
# ../data/raw/unzip_VD/20231101/VDLive_1522.xml
# ../data/raw/unzip_VD/20231101/VDLive_1523.xml
# ../data/raw/unzip_VD/20231101/VDLive_1524.xml
# ../data/raw/unzip_VD/20231101/VDLive_1525.xml
# ../data/raw/unzip_VD/20231101/VDLive_1526.xml
# ../data/raw/unzip_VD/20231101/VDLive_1527.xml
# ../data/raw/unzip_VD/20231101/VDLive_1528.xml
# ../data/raw/unzip_VD/20231101/VDLive_1529.xml
# ../data/raw/unzip_VD/20231101/VDLive_1530.xml
# ../data/raw/unzip_VD/20231101/VDLive_1531.xml
# ../data/raw/unzip_VD/20231101/VDLive_1532.xml
# ../data/raw/unzip_VD/20231101/VDLive_1533.xml
# ../data/raw/unzip_VD/20231101/VDLive_1534.xml
# ../data/raw/unzip_VD/20231101/VDLive_1535.xml
# ../data/raw/unzip_VD/20231101/VDLive_1536.xml
# ../data/raw/unzip_VD/20231101/VDLive_1537.xml
# ../data/raw/unzip_VD/20231101/VDLive_1538.xml
# ../data/raw/unzip_VD/20231101/VDLive_1539.xml
# ../data/raw/unzip_VD/20231101/VDLive_1540.xml
# ../data/raw/unzip_VD/20231101/VDLive_1541.xml
# ../data/raw/unzip_VD/20231101/VDLive_1542.xml
# ../data/raw/unzip_VD/20231101/VDLive_1543.xml
# ../data/raw/unzip_VD/20231101/VDLive_1544.xml
# ../data/raw/unzip_VD/20231101/VDLive_1545.xml
# ../data/raw/unzip_VD/20231101/VDLive_1546.xml
# ../data/raw/unzip_VD/20231101/VDLive_1547.xml
# ../data/raw/unzip_VD/20231101/VDLive_1548.xml
# ../data/raw/unzip_VD/20231101/VDLive_1549.xml
# ../data/raw/unzip_VD/20231101/VDLive_1550.xml
# ../data/raw/unzip_VD/20231101/VDLive_1551.xml
# ../data/raw/unzip_VD/20231101/VDLive_1552.xml
# ../data/raw/unzip_VD/20231101/VDLive_1553.xml
# ../data/raw/unzip_VD/20231101/VDLive_1554.xml
# ../data/raw/unzip_VD/20231101/VDLive_1555.xml
# ../data/raw/unzip_VD/20231101/VDLive_1556.xml
# ../data/raw/unzip_VD/20231101/VDLive_1557.xml
# ../data/raw/unzip_VD/20231101/VDLive_1558.xml
# ../data/raw/unzip_VD/20231101/VDLive_1559.xml
# ../data/raw/unzip_VD/20231101/VDLive_1600.xml
# ../data/raw/unzip_VD/20231101/VDLive_1601.xml
# ../data/raw/unzip_VD/20231101/VDLive_1602.xml
# ../data/raw/unzip_VD/20231101/VDLive_1603.xml
# ../data/raw/unzip_VD/20231101/VDLive_1604.xml
# ../data/raw/unzip_VD/20231101/VDLive_1605.xml
# ../data/raw/unzip_VD/20231101/VDLive_1606.xml
# ../data/raw/unzip_VD/20231101/VDLive_1607.xml
# ../data/raw/unzip_VD/20231101/VDLive_1608.xml
# ../data/raw/unzip_VD/20231101/VDLive_1609.xml
# ../data/raw/unzip_VD/20231101/VDLive_1610.xml
# ../data/raw/unzip_VD/20231101/VDLive_1611.xml
# ../data/raw/unzip_VD/20231101/VDLive_1612.xml
# ../data/raw/unzip_VD/20231101/VDLive_1613.xml
# ../data/raw/unzip_VD/20231101/VDLive_1614.xml
# ../data/raw/unzip_VD/20231101/VDLive_1615.xml
# ../data/raw/unzip_VD/20231101/VDLive_1616.xml
# ../data/raw/unzip_VD/20231101/VDLive_1617.xml
# ../data/raw/unzip_VD/20231101/VDLive_1618.xml
# ../data/raw/unzip_VD/20231101/VDLive_1619.xml
# ../data/raw/unzip_VD/20231101/VDLive_1620.xml
# ../data/raw/unzip_VD/20231101/VDLive_1621.xml
# ../data/raw/unzip_VD/20231101/VDLive_1622.xml
# ../data/raw/unzip_VD/20231101/VDLive_1623.xml
# ../data/raw/unzip_VD/20231101/VDLive_1624.xml
# ../data/raw/unzip_VD/20231101/VDLive_1625.xml
# ../data/raw/unzip_VD/20231101/VDLive_1626.xml
# ../data/raw/unzip_VD/20231101/VDLive_1627.xml
# ../data/raw/unzip_VD/20231101/VDLive_1628.xml
# ../data/raw/unzip_VD/20231101/VDLive_1629.xml
# ../data/raw/unzip_VD/20231101/VDLive_1630.xml
# ../data/raw/unzip_VD/20231101/VDLive_1631.xml
# ../data/raw/unzip_VD/20231101/VDLive_1632.xml
# ../data/raw/unzip_VD/20231101/VDLive_1633.xml
# ../data/raw/unzip_VD/20231101/VDLive_1634.xml
# ../data/raw/unzip_VD/20231101/VDLive_1635.xml
# ../data/raw/unzip_VD/20231101/VDLive_1636.xml
# ../data/raw/unzip_VD/20231101/VDLive_1637.xml
# ../data/raw/unzip_VD/20231101/VDLive_1638.xml
# ../data/raw/unzip_VD/20231101/VDLive_1639.xml
# ../data/raw/unzip_VD/20231101/VDLive_1640.xml
# ../data/raw/unzip_VD/20231101/VDLive_1641.xml
# ../data/raw/unzip_VD/20231101/VDLive_1642.xml
# ../data/raw/unzip_VD/20231101/VDLive_1643.xml
# ../data/raw/unzip_VD/20231101/VDLive_1644.xml
# ../data/raw/unzip_VD/20231101/VDLive_1645.xml
# ../data/raw/unzip_VD/20231101/VDLive_1646.xml
# ../data/raw/unzip_VD/20231101/VDLive_1647.xml
# ../data/raw/unzip_VD/20231101/VDLive_1648.xml
# ../data/raw/unzip_VD/20231101/VDLive_1649.xml
# ../data/raw/unzip_VD/20231101/VDLive_1650.xml
# ../data/raw/unzip_VD/20231101/VDLive_1651.xml
# ../data/raw/unzip_VD/20231101/VDLive_1652.xml
# ../data/raw/unzip_VD/20231101/VDLive_1653.xml
# ../data/raw/unzip_VD/20231101/VDLive_1654.xml
# ../data/raw/unzip_VD/20231101/VDLive_1655.xml
# ../data/raw/unzip_VD/20231101/VDLive_1656.xml
# ../data/raw/unzip_VD/20231101/VDLive_1657.xml
# ../data/raw/unzip_VD/20231101/VDLive_1658.xml
# ../data/raw/unzip_VD/20231101/VDLive_1659.xml
# ../data/raw/unzip_VD/20231101/VDLive_1700.xml
# ../data/raw/unzip_VD/20231101/VDLive_1701.xml
# ../data/raw/unzip_VD/20231101/VDLive_1702.xml
# ../data/raw/unzip_VD/20231101/VDLive_1703.xml
# ../data/raw/unzip_VD/20231101/VDLive_1704.xml
# ../data/raw/unzip_VD/20231101/VDLive_1705.xml
# ../data/raw/unzip_VD/20231101/VDLive_1706.xml
# ../data/raw/unzip_VD/20231101/VDLive_1707.xml
# ../data/raw/unzip_VD/20231101/VDLive_1708.xml
# ../data/raw/unzip_VD/20231101/VDLive_1709.xml
# ../data/raw/unzip_VD/20231101/VDLive_1710.xml
# ../data/raw/unzip_VD/20231101/VDLive_1711.xml
# ../data/raw/unzip_VD/20231101/VDLive_1712.xml
# ../data/raw/unzip_VD/20231101/VDLive_1713.xml
# ../data/raw/unzip_VD/20231101/VDLive_1714.xml
# ../data/raw/unzip_VD/20231101/VDLive_1715.xml
# ../data/raw/unzip_VD/20231101/VDLive_1716.xml
# ../data/raw/unzip_VD/20231101/VDLive_1717.xml
# ../data/raw/unzip_VD/20231101/VDLive_1718.xml
# ../data/raw/unzip_VD/20231101/VDLive_1719.xml
# ../data/raw/unzip_VD/20231101/VDLive_1720.xml
# ../data/raw/unzip_VD/20231101/VDLive_1721.xml
# ...
# ../data/raw/unzip_VD/20231101/VDLive_1814.xml
# ../data/raw/unzip_VD/20231101/VDLive_1815.xml
# ../data/raw/unzip_VD/20231101/VDLive_1816.xml
# ../data/raw/unzip_VD/20231101/VDLive_1817.xml
# ../data/raw/unzip_VD/20231101/VDLive_1818.xml
# ../data/raw/unzip_VD/20231101/VDLive_1819.xml
# ../data/raw/unzip_VD/20231101/VDLive_1820.xml
# ../data/raw/unzip_VD/20231101/VDLive_1821.xml
# ../data/raw/unzip_VD/20231101/VDLive_1822.xml
# ../data/raw/unzip_VD/20231101/VDLive_1823.xml
# ../data/raw/unzip_VD/20231101/VDLive_1824.xml
# ../data/raw/unzip_VD/20231101/VDLive_1825.xml
# ../data/raw/unzip_VD/20231101/VDLive_1826.xml
# ../data/raw/unzip_VD/20231101/VDLive_1827.xml
# ../data/raw/unzip_VD/20231101/VDLive_1828.xml
# ../data/raw/unzip_VD/20231101/VDLive_1829.xml
# ../data/raw/unzip_VD/20231101/VDLive_1830.xml
# ../data/raw/unzip_VD/20231101/VDLive_1831.xml
# ../data/raw/unzip_VD/20231101/VDLive_1832.xml
# ../data/raw/unzip_VD/20231101/VDLive_1833.xml
# ../data/raw/unzip_VD/20231101/VDLive_1834.xml
# ../data/raw/unzip_VD/20231101/VDLive_1835.xml
# ../data/raw/unzip_VD/20231101/VDLive_1836.xml
# ../data/raw/unzip_VD/20231101/VDLive_1837.xml
# ../data/raw/unzip_VD/20231101/VDLive_1838.xml
# ../data/raw/unzip_VD/20231101/VDLive_1839.xml
# ../data/raw/unzip_VD/20231101/VDLive_1840.xml
# ../data/raw/unzip_VD/20231101/VDLive_1841.xml
# ../data/raw/unzip_VD/20231101/VDLive_1842.xml
# ../data/raw/unzip_VD/20231101/VDLive_1843.xml
# ../data/raw/unzip_VD/20231101/VDLive_1844.xml
# ../data/raw/unzip_VD/20231101/VDLive_1845.xml
# ../data/raw/unzip_VD/20231101/VDLive_1846.xml
# ../data/raw/unzip_VD/20231101/VDLive_1847.xml
# ../data/raw/unzip_VD/20231101/VDLive_1848.xml
# ../data/raw/unzip_VD/20231101/VDLive_1849.xml
# ../data/raw/unzip_VD/20231101/VDLive_1850.xml
# ../data/raw/unzip_VD/20231101/VDLive_1851.xml
# ../data/raw/unzip_VD/20231101/VDLive_1852.xml
# ../data/raw/unzip_VD/20231101/VDLive_1853.xml
# ../data/raw/unzip_VD/20231101/VDLive_1854.xml
# ../data/raw/unzip_VD/20231101/VDLive_1855.xml
# ../data/raw/unzip_VD/20231101/VDLive_1856.xml
# ../data/raw/unzip_VD/20231101/VDLive_1857.xml
# ../data/raw/unzip_VD/20231101/VDLive_1858.xml
# ../data/raw/unzip_VD/20231101/VDLive_1859.xml
# ../data/raw/unzip_VD/20231101/VDLive_1900.xml
# ../data/raw/unzip_VD/20231101/VDLive_1901.xml
# ../data/raw/unzip_VD/20231101/VDLive_1902.xml
# ../data/raw/unzip_VD/20231101/VDLive_1903.xml
# ../data/raw/unzip_VD/20231101/VDLive_1904.xml
# ../data/raw/unzip_VD/20231101/VDLive_1905.xml
# ../data/raw/unzip_VD/20231101/VDLive_1906.xml
# ../data/raw/unzip_VD/20231101/VDLive_1907.xml
# ../data/raw/unzip_VD/20231101/VDLive_1908.xml
# ../data/raw/unzip_VD/20231101/VDLive_1909.xml
# ../data/raw/unzip_VD/20231101/VDLive_1910.xml
# ../data/raw/unzip_VD/20231101/VDLive_1911.xml
# ../data/raw/unzip_VD/20231101/VDLive_1912.xml
# ../data/raw/unzip_VD/20231101/VDLive_1913.xml
# ../data/raw/unzip_VD/20231101/VDLive_1914.xml
# ../data/raw/unzip_VD/20231101/VDLive_1915.xml
# ../data/raw/unzip_VD/20231101/VDLive_1916.xml
# ../data/raw/unzip_VD/20231101/VDLive_1917.xml
# ../data/raw/unzip_VD/20231101/VDLive_1918.xml
# ../data/raw/unzip_VD/20231101/VDLive_1919.xml
# ../data/raw/unzip_VD/20231101/VDLive_1920.xml
# ../data/raw/unzip_VD/20231101/VDLive_1921.xml
# ../data/raw/unzip_VD/20231101/VDLive_1922.xml
# ../data/raw/unzip_VD/20231101/VDLive_1923.xml
# ../data/raw/unzip_VD/20231101/VDLive_1924.xml
# ../data/raw/unzip_VD/20231101/VDLive_1925.xml
# ../data/raw/unzip_VD/20231101/VDLive_1926.xml
# ../data/raw/unzip_VD/20231101/VDLive_1927.xml
# ../data/raw/unzip_VD/20231101/VDLive_1928.xml
# ../data/raw/unzip_VD/20231101/VDLive_1929.xml
# ../data/raw/unzip_VD/20231101/VDLive_1930.xml
# ../data/raw/unzip_VD/20231101/VDLive_1931.xml
# ../data/raw/unzip_VD/20231101/VDLive_1932.xml
# ../data/raw/unzip_VD/20231101/VDLive_1933.xml
# ../data/raw/unzip_VD/20231101/VDLive_1934.xml
# ../data/raw/unzip_VD/20231101/VDLive_1935.xml
# ../data/raw/unzip_VD/20231101/VDLive_1936.xml
# ../data/raw/unzip_VD/20231101/VDLive_1937.xml
# ../data/raw/unzip_VD/20231101/VDLive_1938.xml
# ../data/raw/unzip_VD/20231101/VDLive_1939.xml
# ../data/raw/unzip_VD/20231101/VDLive_1940.xml
# ../data/raw/unzip_VD/20231101/VDLive_1941.xml
# ../data/raw/unzip_VD/20231101/VDLive_1942.xml
# ../data/raw/unzip_VD/20231101/VDLive_1943.xml
# ../data/raw/unzip_VD/20231101/VDLive_1944.xml
# ../data/raw/unzip_VD/20231101/VDLive_1945.xml
# ../data/raw/unzip_VD/20231101/VDLive_1946.xml
# ../data/raw/unzip_VD/20231101/VDLive_1947.xml
# ../data/raw/unzip_VD/20231101/VDLive_1948.xml
# ../data/raw/unzip_VD/20231101/VDLive_1949.xml
# ../data/raw/unzip_VD/20231101/VDLive_1950.xml
# ../data/raw/unzip_VD/20231101/VDLive_1951.xml
# ../data/raw/unzip_VD/20231101/VDLive_1952.xml
# ../data/raw/unzip_VD/20231101/VDLive_1953.xml
# ../data/raw/unzip_VD/20231101/VDLive_1954.xml
# ../data/raw/unzip_VD/20231101/VDLive_1955.xml
# ../data/raw/unzip_VD/20231101/VDLive_1956.xml
# ../data/raw/unzip_VD/20231101/VDLive_1957.xml
# ../data/raw/unzip_VD/20231101/VDLive_1958.xml
# ../data/raw/unzip_VD/20231101/VDLive_1959.xml
# ../data/raw/unzip_VD/20231101/VDLive_2000.xml
# ../data/raw/unzip_VD/20231101/VDLive_2001.xml
# ../data/raw/unzip_VD/20231101/VDLive_2002.xml
# ../data/raw/unzip_VD/20231101/VDLive_2003.xml
# ../data/raw/unzip_VD/20231101/VDLive_2004.xml
# ../data/raw/unzip_VD/20231101/VDLive_2005.xml
# ../data/raw/unzip_VD/20231101/VDLive_2006.xml
# ../data/raw/unzip_VD/20231101/VDLive_2007.xml
# ../data/raw/unzip_VD/20231101/VDLive_2008.xml
# ../data/raw/unzip_VD/20231101/VDLive_2009.xml
# ../data/raw/unzip_VD/20231101/VDLive_2010.xml
# ../data/raw/unzip_VD/20231101/VDLive_2011.xml
# ../data/raw/unzip_VD/20231101/VDLive_2012.xml
# ../data/raw/unzip_VD/20231101/VDLive_2013.xml
# ../data/raw/unzip_VD/20231101/VDLive_2014.xml
# ../data/raw/unzip_VD/20231101/VDLive_2015.xml
# ../data/raw/unzip_VD/20231101/VDLive_2016.xml
# ../data/raw/unzip_VD/20231101/VDLive_2017.xml
# ../data/raw/unzip_VD/20231101/VDLive_2018.xml
# ../data/raw/unzip_VD/20231101/VDLive_2019.xml
# ../data/raw/unzip_VD/20231101/VDLive_2020.xml
# ../data/raw/unzip_VD/20231101/VDLive_2021.xml
# ../data/raw/unzip_VD/20231101/VDLive_2022.xml
# ../data/raw/unzip_VD/20231101/VDLive_2023.xml
# ../data/raw/unzip_VD/20231101/VDLive_2024.xml
# ../data/raw/unzip_VD/20231101/VDLive_2025.xml
# ../data/raw/unzip_VD/20231101/VDLive_2026.xml
# ../data/raw/unzip_VD/20231101/VDLive_2027.xml
# ../data/raw/unzip_VD/20231101/VDLive_2028.xml
# ../data/raw/unzip_VD/20231101/VDLive_2029.xml
# ../data/raw/unzip_VD/20231101/VDLive_2030.xml
# ../data/raw/unzip_VD/20231101/VDLive_2031.xml
# ../data/raw/unzip_VD/20231101/VDLive_2032.xml
# ../data/raw/unzip_VD/20231101/VDLive_2033.xml
# ../data/raw/unzip_VD/20231101/VDLive_2034.xml
# ../data/raw/unzip_VD/20231101/VDLive_2035.xml
# ../data/raw/unzip_VD/20231101/VDLive_2036.xml
# ../data/raw/unzip_VD/20231101/VDLive_2037.xml
# ../data/raw/unzip_VD/20231101/VDLive_2038.xml
# ../data/raw/unzip_VD/20231101/VDLive_2039.xml
# ../data/raw/unzip_VD/20231101/VDLive_2040.xml
# ../data/raw/unzip_VD/20231101/VDLive_2041.xml
# ../data/raw/unzip_VD/20231101/VDLive_2042.xml
# ../data/raw/unzip_VD/20231101/VDLive_2043.xml
# ../data/raw/unzip_VD/20231101/VDLive_2044.xml
# ../data/raw/unzip_VD/20231101/VDLive_2045.xml
# ../data/raw/unzip_VD/20231101/VDLive_2046.xml
# ../data/raw/unzip_VD/20231101/VDLive_2047.xml
# ../data/raw/unzip_VD/20231101/VDLive_2048.xml
# ../data/raw/unzip_VD/20231101/VDLive_2049.xml
# ../data/raw/unzip_VD/20231101/VDLive_2050.xml
# ../data/raw/unzip_VD/20231101/VDLive_2051.xml
# ../data/raw/unzip_VD/20231101/VDLive_2052.xml
# ../data/raw/unzip_VD/20231101/VDLive_2053.xml
# ../data/raw/unzip_VD/20231101/VDLive_2054.xml
# ../data/raw/unzip_VD/20231101/VDLive_2055.xml
# ../data/raw/unzip_VD/20231101/VDLive_2056.xml
# ../data/raw/unzip_VD/20231101/VDLive_2057.xml
# ../data/raw/unzip_VD/20231101/VDLive_2058.xml
# ../data/raw/unzip_VD/20231101/VDLive_2059.xml
# ../data/raw/unzip_VD/20231101/VDLive_2100.xml
# ../data/raw/unzip_VD/20231101/VDLive_2101.xml
# ../data/raw/unzip_VD/20231101/VDLive_2102.xml
# ../data/raw/unzip_VD/20231101/VDLive_2103.xml
# ../data/raw/unzip_VD/20231101/VDLive_2104.xml
# ../data/raw/unzip_VD/20231101/VDLive_2105.xml
# ../data/raw/unzip_VD/20231101/VDLive_2106.xml
# ../data/raw/unzip_VD/20231101/VDLive_2107.xml
# ../data/raw/unzip_VD/20231101/VDLive_2108.xml
# ../data/raw/unzip_VD/20231101/VDLive_2109.xml
# ../data/raw/unzip_VD/20231101/VDLive_2110.xml
# ../data/raw/unzip_VD/20231101/VDLive_2111.xml
# ../data/raw/unzip_VD/20231101/VDLive_2112.xml
# ../data/raw/unzip_VD/20231101/VDLive_2113.xml
# ../data/raw/unzip_VD/20231101/VDLive_2114.xml
# ../data/raw/unzip_VD/20231101/VDLive_2115.xml
# ../data/raw/unzip_VD/20231101/VDLive_2116.xml
# ../data/raw/unzip_VD/20231101/VDLive_2117.xml
# ../data/raw/unzip_VD/20231101/VDLive_2118.xml
# ../data/raw/unzip_VD/20231101/VDLive_2119.xml
# ../data/raw/unzip_VD/20231101/VDLive_2120.xml
# ../data/raw/unzip_VD/20231101/VDLive_2121.xml
# ../data/raw/unzip_VD/20231101/VDLive_2122.xml
# ../data/raw/unzip_VD/20231101/VDLive_2123.xml
# ../data/raw/unzip_VD/20231101/VDLive_2124.xml
# ../data/raw/unzip_VD/20231101/VDLive_2125.xml
# ../data/raw/unzip_VD/20231101/VDLive_2126.xml
# ../data/raw/unzip_VD/20231101/VDLive_2127.xml
# ../data/raw/unzip_VD/20231101/VDLive_2128.xml
# ../data/raw/unzip_VD/20231101/VDLive_2129.xml
# ../data/raw/unzip_VD/20231101/VDLive_2130.xml
# ../data/raw/unzip_VD/20231101/VDLive_2131.xml
# ../data/raw/unzip_VD/20231101/VDLive_2132.xml
# ../data/raw/unzip_VD/20231101/VDLive_2133.xml
# ../data/raw/unzip_VD/20231101/VDLive_2134.xml
# ../data/raw/unzip_VD/20231101/VDLive_2135.xml
# ../data/raw/unzip_VD/20231101/VDLive_2136.xml
# ../data/raw/unzip_VD/20231101/VDLive_2137.xml
# ../data/raw/unzip_VD/20231101/VDLive_2138.xml
# ../data/raw/unzip_VD/20231101/VDLive_2139.xml
# ../data/raw/unzip_VD/20231101/VDLive_2140.xml
# ../data/raw/unzip_VD/20231101/VDLive_2141.xml
# ../data/raw/unzip_VD/20231101/VDLive_2142.xml
# ../data/raw/unzip_VD/20231101/VDLive_2143.xml
# ../data/raw/unzip_VD/20231101/VDLive_2144.xml
# ../data/raw/unzip_VD/20231101/VDLive_2145.xml
# ../data/raw/unzip_VD/20231101/VDLive_2146.xml
# ../data/raw/unzip_VD/20231101/VDLive_2147.xml
# ../data/raw/unzip_VD/20231101/VDLive_2148.xml
# ../data/raw/unzip_VD/20231101/VDLive_2149.xml
# ../data/raw/unzip_VD/20231101/VDLive_2150.xml
# ../data/raw/unzip_VD/20231101/VDLive_2151.xml
# ../data/raw/unzip_VD/20231101/VDLive_2152.xml
# ../data/raw/unzip_VD/20231101/VDLive_2153.xml
# ../data/raw/unzip_VD/20231101/VDLive_2154.xml
# ../data/raw/unzip_VD/20231101/VDLive_2155.xml
# ../data/raw/unzip_VD/20231101/VDLive_2156.xml
# ../data/raw/unzip_VD/20231101/VDLive_2157.xml
# ../data/raw/unzip_VD/20231101/VDLive_2158.xml
# ../data/raw/unzip_VD/20231101/VDLive_2159.xml
# ../data/raw/unzip_VD/20231101/VDLive_2200.xml
# ../data/raw/unzip_VD/20231101/VDLive_2201.xml
# ../data/raw/unzip_VD/20231101/VDLive_2202.xml
# ../data/raw/unzip_VD/20231101/VDLive_2203.xml
# ../data/raw/unzip_VD/20231101/VDLive_2204.xml
# ../data/raw/unzip_VD/20231101/VDLive_2205.xml
# ../data/raw/unzip_VD/20231101/VDLive_2206.xml
# ../data/raw/unzip_VD/20231101/VDLive_2207.xml
# ../data/raw/unzip_VD/20231101/VDLive_2208.xml
# ../data/raw/unzip_VD/20231101/VDLive_2209.xml
# ../data/raw/unzip_VD/20231101/VDLive_2210.xml
# ../data/raw/unzip_VD/20231101/VDLive_2211.xml
# ../data/raw/unzip_VD/20231101/VDLive_2212.xml
# ../data/raw/unzip_VD/20231101/VDLive_2213.xml
# ../data/raw/unzip_VD/20231101/VDLive_2214.xml
# ../data/raw/unzip_VD/20231101/VDLive_2215.xml
# ../data/raw/unzip_VD/20231101/VDLive_2216.xml
# ../data/raw/unzip_VD/20231101/VDLive_2217.xml
# ../data/raw/unzip_VD/20231101/VDLive_2218.xml
# ../data/raw/unzip_VD/20231101/VDLive_2219.xml
# ../data/raw/unzip_VD/20231101/VDLive_2220.xml
# ../data/raw/unzip_VD/20231101/VDLive_2221.xml
# ../data/raw/unzip_VD/20231101/VDLive_2222.xml
# ../data/raw/unzip_VD/20231101/VDLive_2223.xml
# ../data/raw/unzip_VD/20231101/VDLive_2224.xml
# ../data/raw/unzip_VD/20231101/VDLive_2225.xml
# ../data/raw/unzip_VD/20231101/VDLive_2226.xml
# ../data/raw/unzip_VD/20231101/VDLive_2227.xml
# ../data/raw/unzip_VD/20231101/VDLive_2228.xml
# ../data/raw/unzip_VD/20231101/VDLive_2229.xml
# ../data/raw/unzip_VD/20231101/VDLive_2230.xml
# ../data/raw/unzip_VD/20231101/VDLive_2231.xml
# ../data/raw/unzip_VD/20231101/VDLive_2232.xml
# ../data/raw/unzip_VD/20231101/VDLive_2233.xml
# ../data/raw/unzip_VD/20231101/VDLive_2234.xml
# ../data/raw/unzip_VD/20231101/VDLive_2235.xml
# ../data/raw/unzip_VD/20231101/VDLive_2236.xml
# ../data/raw/unzip_VD/20231101/VDLive_2237.xml
# ../data/raw/unzip_VD/20231101/VDLive_2238.xml
# ../data/raw/unzip_VD/20231101/VDLive_2239.xml
# ../data/raw/unzip_VD/20231101/VDLive_2240.xml
# ../data/raw/unzip_VD/20231101/VDLive_2241.xml
# ../data/raw/unzip_VD/20231101/VDLive_2242.xml
# ../data/raw/unzip_VD/20231101/VDLive_2243.xml
# ../data/raw/unzip_VD/20231101/VDLive_2244.xml
# ../data/raw/unzip_VD/20231101/VDLive_2245.xml
# ../data/raw/unzip_VD/20231101/VDLive_2246.xml
# ../data/raw/unzip_VD/20231101/VDLive_2247.xml
# ../data/raw/unzip_VD/20231101/VDLive_2248.xml
# ../data/raw/unzip_VD/20231101/VDLive_2249.xml
# ../data/raw/unzip_VD/20231101/VDLive_2250.xml
# ../data/raw/unzip_VD/20231101/VDLive_2251.xml
# ../data/raw/unzip_VD/20231101/VDLive_2252.xml
# ../data/raw/unzip_VD/20231101/VDLive_2253.xml
# ../data/raw/unzip_VD/20231101/VDLive_2254.xml
# ../data/raw/unzip_VD/20231101/VDLive_2255.xml
# ../data/raw/unzip_VD/20231101/VDLive_2256.xml
# ../data/raw/unzip_VD/20231101/VDLive_2257.xml
# ../data/raw/unzip_VD/20231101/VDLive_2258.xml
# ../data/raw/unzip_VD/20231101/VDLive_2259.xml
# ../data/raw/unzip_VD/20231101/VDLive_2300.xml
# ../data/raw/unzip_VD/20231101/VDLive_2301.xml
# ../data/raw/unzip_VD/20231101/VDLive_2302.xml
# ../data/raw/unzip_VD/20231101/VDLive_2303.xml
# ../data/raw/unzip_VD/20231101/VDLive_2304.xml
# ../data/raw/unzip_VD/20231101/VDLive_2305.xml
# ../data/raw/unzip_VD/20231101/VDLive_2306.xml
# ../data/raw/unzip_VD/20231101/VDLive_2307.xml
# ../data/raw/unzip_VD/20231101/VDLive_2308.xml
# ../data/raw/unzip_VD/20231101/VDLive_2309.xml
# ../data/raw/unzip_VD/20231101/VDLive_2310.xml
# ../data/raw/unzip_VD/20231101/VDLive_2311.xml
# ../data/raw/unzip_VD/20231101/VDLive_2312.xml
# ../data/raw/unzip_VD/20231101/VDLive_2313.xml
# ../data/raw/unzip_VD/20231101/VDLive_2314.xml
# ../data/raw/unzip_VD/20231101/VDLive_2315.xml
# ../data/raw/unzip_VD/20231101/VDLive_2316.xml
# ../data/raw/unzip_VD/20231101/VDLive_2317.xml
# ../data/raw/unzip_VD/20231101/VDLive_2318.xml
# ../data/raw/unzip_VD/20231101/VDLive_2319.xml
# ../data/raw/unzip_VD/20231101/VDLive_2320.xml
# ../data/raw/unzip_VD/20231101/VDLive_2321.xml
# ../data/raw/unzip_VD/20231101/VDLive_2322.xml
# ../data/raw/unzip_VD/20231101/VDLive_2323.xml
# ../data/raw/unzip_VD/20231101/VDLive_2324.xml
# ../data/raw/unzip_VD/20231101/VDLive_2325.xml
# ../data/raw/unzip_VD/20231101/VDLive_2326.xml
# ../data/raw/unzip_VD/20231101/VDLive_2327.xml
# ../data/raw/unzip_VD/20231101/VDLive_2328.xml
# ../data/raw/unzip_VD/20231101/VDLive_2329.xml
# ../data/raw/unzip_VD/20231101/VDLive_2330.xml
# ../data/raw/unzip_VD/20231101/VDLive_2331.xml
# ../data/raw/unzip_VD/20231101/VDLive_2332.xml
# ../data/raw/unzip_VD/20231101/VDLive_2333.xml
# ../data/raw/unzip_VD/20231101/VDLive_2334.xml
# ../data/raw/unzip_VD/20231101/VDLive_2335.xml
# ../data/raw/unzip_VD/20231101/VDLive_2336.xml
# ../data/raw/unzip_VD/20231101/VDLive_2337.xml
# ../data/raw/unzip_VD/20231101/VDLive_2338.xml
# ../data/raw/unzip_VD/20231101/VDLive_2339.xml
# ../data/raw/unzip_VD/20231101/VDLive_2340.xml
# ../data/raw/unzip_VD/20231101/VDLive_2341.xml
# ../data/raw/unzip_VD/20231101/VDLive_2342.xml
# ../data/raw/unzip_VD/20231101/VDLive_2343.xml
# ../data/raw/unzip_VD/20231101/VDLive_2344.xml
# ../data/raw/unzip_VD/20231101/VDLive_2345.xml
# ../data/raw/unzip_VD/20231101/VDLive_2346.xml
# ../data/raw/unzip_VD/20231101/VDLive_2347.xml
# ../data/raw/unzip_VD/20231101/VDLive_2348.xml
# ../data/raw/unzip_VD/20231101/VDLive_2349.xml
# ../data/raw/unzip_VD/20231101/VDLive_2350.xml
# ../data/raw/unzip_VD/20231101/VDLive_2351.xml
# ../data/raw/unzip_VD/20231101/VDLive_2352.xml
# ../data/raw/unzip_VD/20231101/VDLive_2353.xml
# ../data/raw/unzip_VD/20231101/VDLive_2354.xml
# ../data/raw/unzip_VD/20231101/VDLive_2355.xml
# ../data/raw/unzip_VD/20231101/VDLive_2356.xml
# ../data/raw/unzip_VD/20231101/VDLive_2357.xml
# ../data/raw/unzip_VD/20231101/VDLive_2358.xml
# ../data/raw/unzip_VD/20231101/VDLive_2359.xml
# 100%|██████████| 1/1 [23:10<00:00, 1390.76s/it]

# %%
# 如果需要刪除整張table的話
# vd_dynamic_tb.delete_table_data()
# 如果怕資料有重複倒入，可以用update_data的方式處理，但會慢一些，因為要比對key value
# vd_dynamic_tb.update_data(df, ...)

# %% [markdown]
# ## ETag Static

# %% [markdown]
# 1天資料 339筆左右

# %%
# UpdateTime：	本平台資料更新時間(ISO8601格式:yyyy-MM-ddTHH:mm:sszzzz)
# UpdateInterval：	本平台資料更新週期(秒)
# AuthorityCode：	業管機關簡碼
# ETagGantryID：	eTag偵測站代碼
# LinkID：	基礎路段代碼, 請參閱[基礎路段代碼表]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# LocationType：	設置地點位置類型 = ['1: 路側', '2: 道路中央分隔島', '3: 快慢分隔島', '4: 車道上門架', '5: 車道鋪面', '6: 其他']
# PositionLon：	設備架設位置 X 坐標
# PositionLat：	設備架設位置 Y 坐標
# RoadID：	道路代碼, 請參閱[路名碼基本資料]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# RoadName：	道路名稱
# RoadClass：	道路分類 = ['0: 國道', '1: 快速道路', '2: 市區快速道路', '3: 省道', '4: 縣道', '5: 鄉道', '6: 市區一般道路', '7: 匝道']
# RoadDirection：	基礎路段所屬道路方向, 請參閱[道路方向資料表]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# Start：	路段起點描述
# End：	路段迄點描述
# LocationMile：	所在方向里程數

# %%
db_path = "../data/hwdb.db"
table_name = "ETAG_STATIC"
columns_in_order = '''
UpdateTime, UpdateInterval, AuthorityCode, LinkVersion, 
ETagGantryID, LinkID, LocationType, PositionLon, PositionLat, 
RoadID, RoadName, RoadClass, RoadDirection, Start, End, LocationMile
'''

etag_static_tb = dc.DatabaseManager(db_path=db_path, 
                                  table_name=table_name)

# %%
# 建立table
etag_static_tb.initialize_table(columns_in_order)

# %%
# Usage 實際需要塞資料時，請參考這邊，使用date_list去找到已經解壓縮路徑底下的資料
# 資料會需要先從xml解析成dict，過程中已經根據原始結構自訂好處理方式了
# 從dict轉換成df的時候會做一些特殊的處理，因為不同資料的字典結構會不太一樣

for date in tqdm(date_list):
    # ETAG_STATIC 的資料都是以 "ETag_0000.xml" 儲存
    upper_file_path = f'../data/raw/unzip_ETag/{date}/'
    file_name_list = os.listdir(upper_file_path)
    file_name_list = [file for file in file_name_list if file.startswith('ETag_0000')]

    for file in file_name_list:
        xml_file_path = upper_file_path + file
        etag_0000 = dc.convert_xml_to_dict(xml_file_path)
        df = dc.etag_static_dict_to_df(etag_0000)
        etag_static_tb.append_data(df) # 可替換成update_data處理
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 25.71it/s]

# %%
# 如果需要刪除整張table的話
# etag_static_tb.delete_table_data()
# 如果怕資料有重複倒入，可以用update_data的方式處理，但會慢一些，因為要比對key value
# etag_static_tb.update_data(df, ...)

# %% [markdown]
# ## ETag Pair

# %% [markdown]
# 一天大概327筆，路徑關係理論上會是固定的，除非有變化

# %%
# UpdateTime：	本平台資料更新時間(ISO8601格式:yyyy-MM-ddTHH:mm:sszzzz)
# UpdateInterval：	本平台資料更新週期(秒)
# AuthorityCode：	業管機關簡碼
# ETagPairID：	eTag 配對路徑代碼
# StartETagGantryID：	eTag配對起始點偵測站代碼
# EndETagGantryID：	eTag配對結束點偵測站代碼
# Description：	配對路徑文字描述
# Distance：	配對路徑距離, GIS提供的配對路徑距離(KM), 可到小數點3位
# StartLinkID：	起點基礎路段代碼, 請參閱[基礎路段代碼表]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# EndLinkID：	迄點基礎路段代碼, 請參閱[基礎路段代碼表]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# Geometry：	配對路徑線型圖資資料, 格式為WKT

# %%
db_path = "../data/hwdb.db"
table_name = "ETAG_PAIR"
columns_in_order = '''
UpdateTime, UpdateInterval, AuthorityCode, ETagPairID,
StartETagGantryID, EndETagGantryID, Description, Distance,
StartLinkID, EndLinkID, Geometry
'''

etag_pair_tb = dc.DatabaseManager(db_path=db_path, 
                                  table_name=table_name)

# %%
# 建立table
etag_pair_tb.initialize_table(columns_in_order)

# %%
# Usage 實際需要塞資料時，請參考這邊，使用date_list去找到已經解壓縮路徑底下的資料
# 資料會需要先從xml解析成dict，過程中已經根據原始結構自訂好處理方式了
# 從dict轉換成df的時候會做一些特殊的處理，因為不同資料的字典結構會不太一樣

for date in tqdm(date_list):
    # ETAG_STATIC 的資料都是以 "ETagPair_0000.xml" 儲存
    upper_file_path = f'../data/raw/unzip_ETag/{date}/'
    file_name_list = os.listdir(upper_file_path)
    file_name_list = [file for file in file_name_list if file.startswith('ETagPair_0000')]

    for file in file_name_list:
        xml_file_path = upper_file_path + file
        etagpair_0000 = dc.convert_xml_to_dict(xml_file_path)
        df = dc.etagpair_dict_to_df(etagpair_0000)
        etag_pair_tb.append_data(df) # 可替換成update_data處理
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 35.81it/s]

# %%
# 如果需要刪除整張table的話
# etag_pair_tb.delete_table_data()
# 如果怕資料有重複倒入，可以用update_data的方式處理，但會慢一些，因為要比對key value
# etag_pair_tb.update_data(df, ...)

# %% [markdown]
# ## ETag Pair Live

# %% [markdown]
# 1天大概 606,240筆

# %%
# UpdateTime：	本平台資料更新時間(ISO8601格式:yyyy-MM-ddTHH:mm:sszzzz)
# UpdateInterval：	本平台資料更新週期(秒)
# AuthorityCode：	業管機關簡碼
# ETagPairID：	ETag 配對路徑編號
# StartETagStatus：	配對起始點設備狀態 = ['0: 正常', '1: 通訊異常', '2: 停用或施工中', '3: 設備故障']
# EndETagStatus：	配對結束點設備狀態 = ['0: 正常', '1: 通訊異常', '2: 停用或施工中', '3: 設備故障']
# VehicleType：	車種代碼, 請參閱[車種代碼]https://traffic-api-documentation.gitbook.io/traffic/xiang-dai-zhao-biao
# TravelTime：	平均旅行時間(指定車種下), 單位:秒, -99=資料異常
# StandardDeviation：	配對樣本數之旅行時間標準差, 單位:秒, -99=資料異常
# SpaceMeanSpeed：	平均車速 (指定車種下), 單位:KM/Hr, -99=資料異常
# VehicleCount：	配對樣本數(指定車種下), 單位:輛
# StartTime：	資料蒐集起始時間(指通過迄點資料) (ISO8601格式:yyyy-MM-ddTHH:mm:sszzzz)
# EndTime：	資料蒐集結束時間(指通過迄點資料) (ISO8601格式:yyyy-MM-ddTHH:mm:sszzzz)
# DataCollectTime：	資料蒐集時間(ISO8601格式:yyyy-MM-ddTHH:mm:sszzzz)

# %%
db_path = "../data/hwdb.db"
table_name = "ETAG_PAIR_LIVE"
columns_in_order = '''
UpdateTime, UpdateInterval, AuthorityCode, ETagPairID,
StartETagStatus, EndETagStatus, VehicleType, TravelTime,
StandardDeviation, SpaceMeanSpeed, VehicleCount, StartTime,
EndTime, DataCollectTime
'''

etag_pairlive_tb = dc.DatabaseManager(db_path=db_path, 
                                  table_name=table_name)

# %%
# 建立table
etag_pairlive_tb.initialize_table(columns_in_order)

# %%
# Usage 實際需要塞資料時，請參考這邊，使用date_list去找到已經解壓縮路徑底下的資料
# 資料會需要先從xml解析成dict，過程中已經根據原始結構自訂好處理方式了
# 從dict轉換成df的時候會做一些特殊的處理，因為不同資料的字典結構會不太一樣
for date in tqdm(date_list):
    # ETAG_STATIC 的資料都是以 "ETagPairLive_XXXX.xml" 儲存
    upper_file_path = f'../data/raw/unzip_ETag/{date}/'
    file_name_list = os.listdir(upper_file_path)
    file_name_list = [file for file in file_name_list if file.startswith('ETagPairLive_')]

    for file in file_name_list:
        xml_file_path = upper_file_path + file
        etagpairlive_ = dc.convert_xml_to_dict(xml_file_path)
        try:
            df = dc.etagpairlive_dict_to_df(etagpairlive_)
            etag_pairlive_tb.append_data(df) # 可替換成update_data處理
        except:
            print(f'{date}資料毀損，檔案為 {file}，先跳過')
# Out:
# 100%|██████████| 1/1 [00:27<00:00, 27.83s/it]

# %%
# 如果需要刪除整張table的話
# etag_pairlive_tb.delete_table_data()
# 如果怕資料有重複倒入，可以用update_data的方式處理，但會慢一些，因為要比對key value
# etag_pairlive_tb.update_data(df, ...)

# %% [markdown]
# ## ETag Vol

# %% [markdown]
# 原始資料為 csv file，每天每小時每五分鐘為一份文件，因此集結起來數量相當大
# 再儲存於輕量級DB中最好不要全年塞再同一張表裡，因此以每個月一張table放置會較合適
# 每個月一張的話，大概是15,132,960筆

# %%
# TimeStamp：	報表時間戳記，即時資料與更新資料時間戳記代表的時間區間不同
#             即時資料：2024-01-01 10:00代表時間區間為2024-01-01 09:55~10:00
#             更新資料：2024-01-01 10:00代表時間區間為2024-01-01 10:00~10:05
# GantryID：	門架編號，門架所在路段詳使用手冊
# Direction：	車行方向，S南、N北
# VehicleType：	車種，31小客車、32小貨車、41大客車、42大貨車、5聯結車
# Volume：	交通量，時間區間內經過單一門架之車流量總量

# %% [markdown]
# 因為這邊開始要用一個月唯一張表的方式來儲存，需要call一個function來解決

# %%
daterange_combinations = dc.generate_daterange_combinations(2023, 11, 2023, 11)
print(daterange_combinations)
# Out:
# [['20231101', '20231130']]

# %%
# predefine，後續主要修改的就是這塊而已
upper_file_path = '../data/raw/unzip_etag_gantry_vol/M03A'
db_path = "../data/hwdb.db"
table_name_prefix = "ETAG_M03A"
columns_in_order = '''
TimeStamp, GantryID, Direction, VehicleType, Volume
'''
col_names = columns_in_order.replace(' ', '').replace('\n', '').split(',')

# 組裝
for index, item in enumerate(daterange_combinations):
    start_date, end_date = item[0], item[1]
    current_year_month = start_date[0:6]
    date_list = ds.generate_date_strings(start_date, end_date)
    
    # define db table name and instance the db manager
    table_name = f"{table_name_prefix}_{current_year_month}"
    etag_temp_tb = dc.DatabaseManager(db_path=db_path, table_name=table_name)
    
    # initialize table
    try: 
        etag_temp_tb.initialize_table(columns_in_order)
        print(f'table: {table_name} initialized')
    except:
        print('something wrong with the initialization')
        
    # append table
    try:
        # 每小時會是一組資料夾
        time_list = [f'{i:02}' for i in range(24)]
        for date in tqdm(date_list):
            # 鎖定特定日期資料夾，只拿包含VDLive開頭的資料名稱
            for time in time_list: 
                file_name_list = os.listdir(f'{upper_file_path}/{date}/{time}/')
                file_name_list = [file for file in file_name_list if file.startswith('TDCS_M03A_')]
            
                for file in file_name_list:
                    csv_file_path = f'{upper_file_path}/{date}/{time}/{file}'
                    df = pd.read_csv(csv_file_path, names=col_names)
                    df['TimeStamp'] = pd.to_datetime(df['TimeStamp'], format='%Y-%m-%d %H:%M')
                    etag_temp_tb.append_data(df)
    except:
        print(f'something wrong during the table append procedure under {current_year_month}')
    
    print(f'{table_name} data insertion complete!')
# Out:
# table: ETAG_M03A_202311 initialized
#   3%|▎         | 1/30 [00:05<02:51,  5.91s/it]
# something wrong during the table append procedure under 202311
# ETAG_M03A_202311 data insertion complete!

# %% [markdown]
# 上面展示的部分因為只有放入一天資料(488,160筆)，所以會進入except環節

# %% [markdown]
# ## ETag Speed

# %% [markdown]
# 1天的資料大概是 606,240筆

# %%
# TimeStamp：	報表時間戳記，即時資料與更新資料時間戳記代表的時間區間不同
#             即時資料：2024-01-01 10:00代表時間區間為2024-01-01 09:55~10:00
#             更新資料：2024-01-01 10:00代表時間區間為2024-01-01 10:00~10:05
# GantryFrom：	上游門架編號，門架所在路段詳使用手冊
# GantryTo：	下游門架編號，門架所在路段詳使用手冊
# VehicleType：	車種，31小客車、32小貨車、41大客車、42大貨車、5聯結車
# Speed：	中位數車速，計算單位為秒
# Volume：	交通量，時間區間內經過上下游門架之車流量總量

# %% [markdown]
# 要特別注意的是塞入sqlite db 中TimeStamp的格式要先處理好，Vol, Speed, Travel Time在裡面稍微不太一樣，需要異動

# %%
# predefine，後續主要修改的就是這塊而已
upper_file_path = '../data/raw/unzip_etag_intergantry_speed/M05A'
db_path = "../data/hwdb.db"
table_name_prefix = "ETAG_M05A"
columns_in_order = '''
TimeStamp, GantryFrom, GantryTo, VehicleType, Speed, Volume
'''
col_names = columns_in_order.replace(' ', '').replace('\n', '').split(',')

# 組裝
for index, item in enumerate(daterange_combinations):
    start_date, end_date = item[0], item[1]
    current_year_month = start_date[0:6]
    date_list = ds.generate_date_strings(start_date, end_date)
    
    # define db table name and instance the db manager
    table_name = f"{table_name_prefix}_{current_year_month}"
    etag_temp_tb = dc.DatabaseManager(db_path=db_path, table_name=table_name)
    
    # initialize table
    try: 
        etag_temp_tb.initialize_table(columns_in_order)
        print(f'table: {table_name} initialized')
    except:
        print('something wrong with the initialization')
        
    # append table
    try:
        # 每小時會是一組資料夾
        time_list = [f'{i:02}' for i in range(24)]
        for date in tqdm(date_list):
            # 鎖定特定日期資料夾，只拿包含VDLive開頭的資料名稱
            for time in time_list: 
                file_name_list = os.listdir(f'{upper_file_path}/{date}/{time}/')
                file_name_list = [file for file in file_name_list if file.startswith('TDCS_M05A_')]
                for file in file_name_list:
                    csv_file_path = f'{upper_file_path}/{date}/{time}/{file}'
                    df = pd.read_csv(csv_file_path, names=col_names)
                    df['TimeStamp'] = pd.to_datetime(df['TimeStamp'], format='%Y/%m/%d %H:%M')
                    etag_temp_tb.append_data(df)
    except:
        print(f'something wrong during the table append procedure under {current_year_month}')
    
    print(f'{table_name} data insertion complete!')
# Out:
# table: ETAG_M05A_202311 initialized
#   3%|▎         | 1/30 [00:04<02:07,  4.38s/it]
# something wrong during the table append procedure under 202311
# ETAG_M05A_202311 data insertion complete!

# %% [markdown]
# ## ETag Travel Time

# %% [markdown]
# 1天大概 606,240筆

# %% [markdown]
# TimeStamp：	報表時間戳記，以下游門架時間戳記代表，此外即時與更新資料時間戳記代表的時間區間不同
#             即時資料：2024-01-01 10:00代表時間區間為2024-01-01 09:55 ~ 10:00
#             更新資料：2024-01-01 10:00代表時間區間為2024-01-01 10:00 ~ 10:05
# GantryFrom：	上游門架編號，門架所在路段詳使用手冊
# GantryTo：	下游門架編號，門架所在路段詳使用手冊
# VehicleType：	車種，31小客車、32小貨車、41大客車、42大貨車、5聯結車
# TravelTime：	中位數旅行時間，計算單位為秒
# Traffic：	交通量，時間區間內經過上下游門架之車流量總量

# %%
# predefine，後續主要修改的就是這塊而已
upper_file_path = '../data/raw/unzip_etag_intergantry_traveltime/M04A'
db_path = "../data/hwdb.db"
table_name_prefix = "ETAG_M04A"
columns_in_order = '''
TimeStamp, GantryFrom, GantryTo, VehicleType, TravelTime, Traffic
'''
col_names = columns_in_order.replace(' ', '').replace('\n', '').split(',')

# 組裝
for index, item in enumerate(daterange_combinations):
    start_date, end_date = item[0], item[1]
    current_year_month = start_date[0:6]
    date_list = ds.generate_date_strings(start_date, end_date)
    
    # define db table name and instance the db manager
    table_name = f"{table_name_prefix}_{current_year_month}"
    etag_temp_tb = dc.DatabaseManager(db_path=db_path, table_name=table_name)
    
    # initialize table
    try: 
        etag_temp_tb.initialize_table(columns_in_order)
        print(f'table: {table_name} initialized')
    except:
        print('something wrong with the initialization')
        
    # append table
    try:
        # 每小時會是一組資料夾
        time_list = [f'{i:02}' for i in range(24)]
        for date in tqdm(date_list):
            # 鎖定特定日期資料夾，只拿包含VDLive開頭的資料名稱
            for time in time_list: 
                file_name_list = os.listdir(f'{upper_file_path}/{date}/{time}/')
                file_name_list = [file for file in file_name_list if file.startswith('TDCS_M04A_')]
                for file in file_name_list:
                    csv_file_path = f'{upper_file_path}/{date}/{time}/{file}'
                    df = pd.read_csv(csv_file_path, names=col_names)
                    df['TimeStamp'] = pd.to_datetime(df['TimeStamp'], format='%Y/%m/%d %H:%M')
                    etag_temp_tb.append_data(df)
    except:
        print(f'something wrong during the table append procedure under {current_year_month}')
    
    print(f'{table_name} data insertion complete!')
# Out:
# table: ETAG_M04A_202311 initialized
#   7%|▋         | 2/30 [00:08<02:05,  4.47s/it]
# something wrong during the table append procedure under 202311
# ETAG_M04A_202311 data insertion complete!
